# %% [markdown]
# # Neural machine translation

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ## Download and prepare the dataset
#
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# Out:
# --2020-12-16 18:52:38--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 172.67.173.198, 104.24.108.196, 104.24.109.196, ...
# Connecting to www.manythings.org (www.manythings.org)|172.67.173.198|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13811083 (13M) [application/zip]
# Saving to: ‘rus-eng.zip.1’
#
# rus-eng.zip.1       100%[===================>]  13.17M  4.61MB/s    in 2.9s
#
# 2020-12-16 18:52:41 (4.61 MB/s) - ‘rus-eng.zip.1’ saved [13811083/13811083]

# %%
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/
# Out:
# mkdir: cannot create directory ‘rus-eng’: File exists
# Archive:  rus-eng.zip
# replace rus-eng/rus.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !ls /content/rus-eng/ -lah
# Out:
# total 66M
# drwxr-xr-x 2 root root 4.0K Dec 16 16:21 .
# drwxr-xr-x 1 root root 4.0K Dec 16 18:52 ..
# -rw-r--r-- 1 root root 1.5K Nov 22 01:35 _about.txt
# -rw-r--r-- 1 root root  66M Nov 22 01:35 rus.txt

# %%
# Download the file
path_to_file = "/content/rus-eng/rus.txt"

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENGLISH, SPANISH]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[-1])
print(ru[-1])
# Out:
# <start> doubtless there exists in this world precisely the right woman for any given man to marry and vice versa but when you consider that a human being has the opportunity of being acquainted with only a few hundred people , and out of the few hundred that there are but a dozen or less whom he knows intimately , and out of the dozen , one or two friends at most , it will easily be seen , when we remember the number of millions who inhabit this world , that probably , since the earth was created , the right man has never yet met the right woman . <end>
# <start> несомненно , для каждого мужчины в этом мире где то есть подходящая женщина , которая может стать ему женой , обратное верно и для женщин . но если учесть , что у человека может быть максимум несколько сотен знакомых , из которых лишь дюжина , а то и меньше , тех , кого он знает близко , а из этой дюжины у него один или от силы два друга , то можно легко увидеть , что с уч том миллионов живущих на земле людей , ни один подходящий мужчина , возможно , ещ не встретил подходящую женщину . <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (414010, 414010)

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 19 ----> он
# 19750 ----> придвинулся
# 99 ----> к
# 471 ----> ней
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 27 ----> he
# 880 ----> moved
# 416 ----> close
# 11 ----> to
# 113 ----> her
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
# print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    # self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden):
    # enc_output shape == (batch_size, max_length, hidden_size)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x, initial_state=hidden)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %%
decoder_sample_h.shape
# Out:
# TensorShape([64, 1024])

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, dec_hidden)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.6638
# Epoch 1 Batch 100 Loss 2.0948
# Epoch 1 Batch 200 Loss 1.9077
# Epoch 1 Batch 300 Loss 1.6475
# Epoch 1 Batch 400 Loss 1.6385
# Epoch 1 Batch 500 Loss 1.4309
# Epoch 1 Batch 600 Loss 1.3257
# Epoch 1 Batch 700 Loss 1.2615
# Epoch 1 Batch 800 Loss 1.2624
# Epoch 1 Batch 900 Loss 1.0637
# Epoch 1 Batch 1000 Loss 1.0764
# Epoch 1 Batch 1100 Loss 1.0107
# Epoch 1 Batch 1200 Loss 1.0225
# Epoch 1 Loss 1.4678
# Time taken for 1 epoch 125.6940860748291 sec
#
# Epoch 2 Batch 0 Loss 0.9713
# Epoch 2 Batch 100 Loss 0.8695
# Epoch 2 Batch 200 Loss 0.8453
# Epoch 2 Batch 300 Loss 0.8580
# Epoch 2 Batch 400 Loss 0.8040
# Epoch 2 Batch 500 Loss 0.7822
# Epoch 2 Batch 600 Loss 0.8146
# Epoch 2 Batch 700 Loss 0.6624
# Epoch 2 Batch 800 Loss 0.7380
# Epoch 2 Batch 900 Loss 0.6636
# Epoch 2 Batch 1000 Loss 0.7200
# Epoch 2 Batch 1100 Loss 0.6137
# Epoch 2 Batch 1200 Loss 0.5621
# Epoch 2 Loss 0.7356
# Time taken for 1 epoch 116.94388222694397 sec
#
# Epoch 3 Batch 0 Loss 0.3952
# Epoch 3 Batch 100 Loss 0.4633
# Epoch 3 Batch 200 Loss 0.3390
# Epoch 3 Batch 300 Loss 0.4519
# Epoch 3 Batch 400 Loss 0.4505
# Epoch 3 Batch 500 Loss 0.4193
# Epoch 3 Batch 600 Loss 0.4579
# Epoch 3 Batch 700 Loss 0.3462
# Epoch 3 Batch 800 Loss 0.3552
# Epoch 3 Batch 900 Loss 0.3351
# Epoch 3 Batch 1000 Loss 0.4149
# Epoch 3 Batch 1100 Loss 0.3871
# Epoch 3 Batch 1200 Loss 0.3239
# Epoch 3 Loss 0.3919
# Time taken for 1 epoch 116.1934461593628 sec
#
# Epoch 4 Batch 0 Loss 0.2074
# Epoch 4 Batch 100 Loss 0.3072
# Epoch 4 Batch 200 Loss 0.1838
# Epoch 4 Batch 300 Loss 0.2402
# Epoch 4 Batch 400 Loss 0.2052
# Epoch 4 Batch 500 Loss 0.2145
# Epoch 4 Batch 600 Loss 0.1951
# Epoch 4 Batch 700 Loss 0.2291
# Epoch 4 Batch 800 Loss 0.2118
# Epoch 4 Batch 900 Loss 0.2260
# Epoch 4 Batch 1000 Loss 0.2624
# Epoch 4 Batch 1100 Loss 0.2472
# Epoch 4 Batch 1200 Loss 0.2353
# Epoch 4 Loss 0.2296
# Time taken for 1 epoch 116.53984379768372 sec
#
# Epoch 5 Batch 0 Loss 0.1338
# Epoch 5 Batch 100 Loss 0.1532
# Epoch 5 Batch 200 Loss 0.1148
# Epoch 5 Batch 300 Loss 0.1402
# Epoch 5 Batch 400 Loss 0.1333
# Epoch 5 Batch 500 Loss 0.1783
# Epoch 5 Batch 600 Loss 0.1912
# Epoch 5 Batch 700 Loss 0.2000
# Epoch 5 Batch 800 Loss 0.1492
# Epoch 5 Batch 900 Loss 0.1298
# Epoch 5 Batch 1000 Loss 0.1857
# Epoch 5 Batch 1100 Loss 0.2238
# Epoch 5 Batch 1200 Loss 0.2120
# Epoch 5 Loss 0.1538
# Time taken for 1 epoch 116.03442144393921 sec
#
# Epoch 6 Batch 0 Loss 0.1229
# Epoch 6 Batch 100 Loss 0.0741
# Epoch 6 Batch 200 Loss 0.0818
# Epoch 6 Batch 300 Loss 0.1174
# Epoch 6 Batch 400 Loss 0.1202
# Epoch 6 Batch 500 Loss 0.0946
# Epoch 6 Batch 600 Loss 0.1339
# Epoch 6 Batch 700 Loss 0.1128
# Epoch 6 Batch 800 Loss 0.1322
# Epoch 6 Batch 900 Loss 0.1387
# Epoch 6 Batch 1000 Loss 0.1184
# Epoch 6 Batch 1100 Loss 0.1028
# Epoch 6 Batch 1200 Loss 0.1117
# Epoch 6 Loss 0.1181
# Time taken for 1 epoch 116.45167326927185 sec
#
# Epoch 7 Batch 0 Loss 0.0686
# Epoch 7 Batch 100 Loss 0.0467
# Epoch 7 Batch 200 Loss 0.0777
# Epoch 7 Batch 300 Loss 0.0888
# Epoch 7 Batch 400 Loss 0.0767
# Epoch 7 Batch 500 Loss 0.1160
# Epoch 7 Batch 600 Loss 0.1167
# Epoch 7 Batch 700 Loss 0.0942
# Epoch 7 Batch 800 Loss 0.1030
# Epoch 7 Batch 900 Loss 0.1266
# Epoch 7 Batch 1000 Loss 0.1179
# Epoch 7 Batch 1100 Loss 0.1424
# Epoch 7 Batch 1200 Loss 0.0970
# Epoch 7 Loss 0.1002
# Time taken for 1 epoch 115.66896295547485 sec
#
# Epoch 8 Batch 0 Loss 0.0847
# Epoch 8 Batch 100 Loss 0.0783
# Epoch 8 Batch 200 Loss 0.1352
# Epoch 8 Batch 300 Loss 0.0850
# Epoch 8 Batch 400 Loss 0.0472
# Epoch 8 Batch 500 Loss 0.0818
# Epoch 8 Batch 600 Loss 0.0730
# Epoch 8 Batch 700 Loss 0.1275
# Epoch 8 Batch 800 Loss 0.1057
# Epoch 8 Batch 900 Loss 0.1251
# Epoch 8 Batch 1000 Loss 0.0781
# Epoch 8 Batch 1100 Loss 0.0790
# Epoch 8 Batch 1200 Loss 0.1040
# Epoch 8 Loss 0.0904
# Time taken for 1 epoch 116.24602174758911 sec
#
# Epoch 9 Batch 0 Loss 0.0561
# Epoch 9 Batch 100 Loss 0.0864
# Epoch 9 Batch 200 Loss 0.0492
# Epoch 9 Batch 300 Loss 0.0533
# Epoch 9 Batch 400 Loss 0.1049
# Epoch 9 Batch 500 Loss 0.0872
# Epoch 9 Batch 600 Loss 0.0984
# Epoch 9 Batch 700 Loss 0.1053
# Epoch 9 Batch 800 Loss 0.1003
# Epoch 9 Batch 900 Loss 0.0950
# Epoch 9 Batch 1000 Loss 0.0907
# Epoch 9 Batch 1100 Loss 0.1385
# Epoch 9 Batch 1200 Loss 0.1469
# Epoch 9 Loss 0.0833
# Time taken for 1 epoch 116.16037678718567 sec
#
# Epoch 10 Batch 0 Loss 0.0624
# Epoch 10 Batch 100 Loss 0.0442
# Epoch 10 Batch 200 Loss 0.0496
# Epoch 10 Batch 300 Loss 0.0474
# Epoch 10 Batch 400 Loss 0.0563
# Epoch 10 Batch 500 Loss 0.0683
# Epoch 10 Batch 600 Loss 0.1115
# Epoch 10 Batch 700 Loss 0.1090
# Epoch 10 Batch 800 Loss 0.0688
# Epoch 10 Batch 900 Loss 0.1011
# Epoch 10 Batch 1000 Loss 0.0794
# Epoch 10 Batch 1100 Loss 0.1018
# Epoch 10 Batch 1200 Loss 0.1297
# Epoch 10 Loss 0.0791
# Time taken for 1 epoch 116.53877711296082 sec
#
# Epoch 11 Batch 0 Loss 0.0771
# Epoch 11 Batch 100 Loss 0.0679
# Epoch 11 Batch 200 Loss 0.0942
# Epoch 11 Batch 300 Loss 0.0801
# Epoch 11 Batch 400 Loss 0.0861
# Epoch 11 Batch 500 Loss 0.0638
# Epoch 11 Batch 600 Loss 0.0949
# Epoch 11 Batch 700 Loss 0.0719
# Epoch 11 Batch 800 Loss 0.0810
# Epoch 11 Batch 900 Loss 0.0465
# Epoch 11 Batch 1000 Loss 0.1024
# Epoch 11 Batch 1100 Loss 0.0818
# Epoch 11 Batch 1200 Loss 0.1195
# Epoch 11 Loss 0.0756
# Time taken for 1 epoch 115.91959023475647 sec
#
# Epoch 12 Batch 0 Loss 0.0344
# Epoch 12 Batch 100 Loss 0.0754
# Epoch 12 Batch 200 Loss 0.0627
# Epoch 12 Batch 300 Loss 0.0497
# Epoch 12 Batch 400 Loss 0.0551
# Epoch 12 Batch 500 Loss 0.0739
# Epoch 12 Batch 600 Loss 0.0409
# Epoch 12 Batch 700 Loss 0.0810
# Epoch 12 Batch 800 Loss 0.0472
# Epoch 12 Batch 900 Loss 0.0885
# Epoch 12 Batch 1000 Loss 0.0971
# Epoch 12 Batch 1100 Loss 0.0938
# Epoch 12 Batch 1200 Loss 0.0626
# Epoch 12 Loss 0.0720
# Time taken for 1 epoch 115.81766486167908 sec
#
# Epoch 13 Batch 0 Loss 0.0430
# Epoch 13 Batch 100 Loss 0.0214
# Epoch 13 Batch 200 Loss 0.0428
# Epoch 13 Batch 300 Loss 0.0324
# Epoch 13 Batch 400 Loss 0.0466
# Epoch 13 Batch 500 Loss 0.1048
# Epoch 13 Batch 600 Loss 0.1056
# Epoch 13 Batch 700 Loss 0.0523
# Epoch 13 Batch 800 Loss 0.0890
# Epoch 13 Batch 900 Loss 0.0557
# Epoch 13 Batch 1000 Loss 0.1168
# Epoch 13 Batch 1100 Loss 0.1235
# Epoch 13 Batch 1200 Loss 0.1293
# Epoch 13 Loss 0.0702
# Time taken for 1 epoch 116.98206949234009 sec
#
# Epoch 14 Batch 0 Loss 0.0529
# Epoch 14 Batch 100 Loss 0.0818
# Epoch 14 Batch 200 Loss 0.0719
# Epoch 14 Batch 300 Loss 0.1000
# Epoch 14 Batch 400 Loss 0.0562
# Epoch 14 Batch 500 Loss 0.0577
# Epoch 14 Batch 600 Loss 0.0886
# Epoch 14 Batch 700 Loss 0.0888
# Epoch 14 Batch 800 Loss 0.0839
# Epoch 14 Batch 900 Loss 0.0812
# Epoch 14 Batch 1000 Loss 0.0551
# Epoch 14 Batch 1100 Loss 0.0708
# Epoch 14 Batch 1200 Loss 0.1179
# Epoch 14 Loss 0.0679
# Time taken for 1 epoch 118.68264508247375 sec
#
# Epoch 15 Batch 0 Loss 0.0337
# Epoch 15 Batch 100 Loss 0.0431
# Epoch 15 Batch 200 Loss 0.0619
# Epoch 15 Batch 300 Loss 0.0359
# Epoch 15 Batch 400 Loss 0.0595
# Epoch 15 Batch 500 Loss 0.0788
# Epoch 15 Batch 600 Loss 0.0544
# Epoch 15 Batch 700 Loss 0.0730
# Epoch 15 Batch 800 Loss 0.0694
# Epoch 15 Batch 900 Loss 0.0195
# Epoch 15 Batch 1000 Loss 0.0925
# Epoch 15 Batch 1100 Loss 0.0555
# Epoch 15 Batch 1200 Loss 0.0773
# Epoch 15 Loss 0.0668
# Time taken for 1 epoch 117.70594525337219 sec
#
# Epoch 16 Batch 0 Loss 0.1127
# Epoch 16 Batch 100 Loss 0.0736
# Epoch 16 Batch 200 Loss 0.0309
# Epoch 16 Batch 300 Loss 0.0345
# Epoch 16 Batch 400 Loss 0.0423
# Epoch 16 Batch 500 Loss 0.0390
# Epoch 16 Batch 600 Loss 0.0555
# Epoch 16 Batch 700 Loss 0.0598
# Epoch 16 Batch 800 Loss 0.0814
# Epoch 16 Batch 900 Loss 0.0870
# Epoch 16 Batch 1000 Loss 0.0540
# Epoch 16 Batch 1100 Loss 0.0449
# Epoch 16 Batch 1200 Loss 0.0969
# Epoch 16 Loss 0.0652
# Time taken for 1 epoch 117.19733929634094 sec
#
# Epoch 17 Batch 0 Loss 0.0542
# Epoch 17 Batch 100 Loss 0.0459
# Epoch 17 Batch 200 Loss 0.0436
# Epoch 17 Batch 300 Loss 0.0473
# Epoch 17 Batch 400 Loss 0.0353
# Epoch 17 Batch 500 Loss 0.1002
# Epoch 17 Batch 600 Loss 0.0472
# Epoch 17 Batch 700 Loss 0.0636
# Epoch 17 Batch 800 Loss 0.0457
# Epoch 17 Batch 900 Loss 0.0645
# Epoch 17 Batch 1000 Loss 0.0714
# Epoch 17 Batch 1100 Loss 0.0474
# Epoch 17 Batch 1200 Loss 0.0910
# Epoch 17 Loss 0.0630
# Time taken for 1 epoch 117.14479613304138 sec
#
# Epoch 18 Batch 0 Loss 0.0366
# Epoch 18 Batch 100 Loss 0.0649
# Epoch 18 Batch 200 Loss 0.0635
# Epoch 18 Batch 300 Loss 0.0686
# Epoch 18 Batch 400 Loss 0.0555
# Epoch 18 Batch 500 Loss 0.0659
# Epoch 18 Batch 600 Loss 0.0748
# Epoch 18 Batch 700 Loss 0.0473
# Epoch 18 Batch 800 Loss 0.0603
# Epoch 18 Batch 900 Loss 0.0828
# Epoch 18 Batch 1000 Loss 0.0518
# Epoch 18 Batch 1100 Loss 0.0712
# Epoch 18 Batch 1200 Loss 0.0861
# Epoch 18 Loss 0.0628
# Time taken for 1 epoch 116.98332905769348 sec
#
# Epoch 19 Batch 0 Loss 0.0346
# Epoch 19 Batch 100 Loss 0.0458
# Epoch 19 Batch 200 Loss 0.0440
# Epoch 19 Batch 300 Loss 0.0688
# Epoch 19 Batch 400 Loss 0.0447
# Epoch 19 Batch 500 Loss 0.0625
# Epoch 19 Batch 600 Loss 0.0544
# Epoch 19 Batch 700 Loss 0.0679
# Epoch 19 Batch 800 Loss 0.0926
# Epoch 19 Batch 900 Loss 0.0593
# Epoch 19 Batch 1000 Loss 0.0401
# Epoch 19 Batch 1100 Loss 0.0544
# Epoch 19 Batch 1200 Loss 0.0916
# Epoch 19 Loss 0.0615
# Time taken for 1 epoch 117.63008522987366 sec
#
# Epoch 20 Batch 0 Loss 0.0865
# Epoch 20 Batch 100 Loss 0.0315
# Epoch 20 Batch 200 Loss 0.0309
# Epoch 20 Batch 300 Loss 0.0483
# Epoch 20 Batch 400 Loss 0.0395
# Epoch 20 Batch 500 Loss 0.0759
# Epoch 20 Batch 600 Loss 0.0689
# Epoch 20 Batch 700 Loss 0.0610
# Epoch 20 Batch 800 Loss 0.0696
# Epoch 20 Batch 900 Loss 0.0718
# Epoch 20 Batch 1000 Loss 0.1182
# Epoch 20 Batch 1100 Loss 0.0683
# Epoch 20 Batch 1200 Loss 0.0782
# Epoch 20 Loss 0.0607
# Time taken for 1 epoch 116.63011431694031 sec
#
# Epoch 21 Batch 0 Loss 0.0612
# Epoch 21 Batch 100 Loss 0.0369
# Epoch 21 Batch 200 Loss 0.0211
# Epoch 21 Batch 300 Loss 0.0298
# Epoch 21 Batch 400 Loss 0.0589
# Epoch 21 Batch 500 Loss 0.0710
# Epoch 21 Batch 600 Loss 0.0639
# Epoch 21 Batch 700 Loss 0.1000
# Epoch 21 Batch 800 Loss 0.0361
# Epoch 21 Batch 900 Loss 0.0593
# Epoch 21 Batch 1000 Loss 0.0633
# Epoch 21 Batch 1100 Loss 0.0640
# Epoch 21 Batch 1200 Loss 0.1114
# Epoch 21 Loss 0.0587
# Time taken for 1 epoch 115.87460398674011 sec
#
# Epoch 22 Batch 0 Loss 0.0386
# Epoch 22 Batch 100 Loss 0.0443
# Epoch 22 Batch 200 Loss 0.0565
# Epoch 22 Batch 300 Loss 0.0537
# Epoch 22 Batch 400 Loss 0.0272
# Epoch 22 Batch 500 Loss 0.0584
# Epoch 22 Batch 600 Loss 0.0672
# Epoch 22 Batch 700 Loss 0.0520
# Epoch 22 Batch 800 Loss 0.0334
# Epoch 22 Batch 900 Loss 0.0828
# Epoch 22 Batch 1000 Loss 0.0309
# Epoch 22 Batch 1100 Loss 0.0485
# Epoch 22 Batch 1200 Loss 0.0725
# Epoch 22 Loss 0.0585
# Time taken for 1 epoch 115.83671188354492 sec
#
# Epoch 23 Batch 0 Loss 0.0606
# Epoch 23 Batch 100 Loss 0.0513
# Epoch 23 Batch 200 Loss 0.0471
# Epoch 23 Batch 300 Loss 0.0899
# Epoch 23 Batch 400 Loss 0.0418
# Epoch 23 Batch 500 Loss 0.0495
# Epoch 23 Batch 600 Loss 0.0603
# Epoch 23 Batch 700 Loss 0.0666
# Epoch 23 Batch 800 Loss 0.0768
# Epoch 23 Batch 900 Loss 0.0562
# Epoch 23 Batch 1000 Loss 0.0356
# Epoch 23 Batch 1100 Loss 0.0665
# Epoch 23 Batch 1200 Loss 0.0481
# Epoch 23 Loss 0.0575
# Time taken for 1 epoch 115.12178301811218 sec
#
# Epoch 24 Batch 0 Loss 0.0463
# Epoch 24 Batch 100 Loss 0.0385
# Epoch 24 Batch 200 Loss 0.0289
# Epoch 24 Batch 300 Loss 0.0625
# Epoch 24 Batch 400 Loss 0.0648
# Epoch 24 Batch 500 Loss 0.0573
# Epoch 24 Batch 600 Loss 0.0391
# Epoch 24 Batch 700 Loss 0.0545
# Epoch 24 Batch 800 Loss 0.0759
# Epoch 24 Batch 900 Loss 0.0393
# Epoch 24 Batch 1000 Loss 0.0710
# Epoch 24 Batch 1100 Loss 0.0808
# Epoch 24 Batch 1200 Loss 0.0510
# Epoch 24 Loss 0.0562
# Time taken for 1 epoch 115.98008680343628 sec
#
# Epoch 25 Batch 0 Loss 0.0689
# Epoch 25 Batch 100 Loss 0.0443
# Epoch 25 Batch 200 Loss 0.0432
# Epoch 25 Batch 300 Loss 0.0562
# Epoch 25 Batch 400 Loss 0.0724
# Epoch 25 Batch 500 Loss 0.0528
# Epoch 25 Batch 600 Loss 0.0622
# Epoch 25 Batch 700 Loss 0.0723
# Epoch 25 Batch 800 Loss 0.0368
# Epoch 25 Batch 900 Loss 0.0767
# Epoch 25 Batch 1000 Loss 0.0761
# Epoch 25 Batch 1100 Loss 0.0694
# Epoch 25 Batch 1200 Loss 0.0833
# Epoch 25 Loss 0.0555
# Time taken for 1 epoch 117.02467966079712 sec
#
# Epoch 26 Batch 0 Loss 0.0432
# Epoch 26 Batch 100 Loss 0.0319
# Epoch 26 Batch 200 Loss 0.0438
# Epoch 26 Batch 300 Loss 0.0514
# Epoch 26 Batch 400 Loss 0.0277
# Epoch 26 Batch 500 Loss 0.0663
# Epoch 26 Batch 600 Loss 0.0305
# Epoch 26 Batch 700 Loss 0.0523
# Epoch 26 Batch 800 Loss 0.0591
# Epoch 26 Batch 900 Loss 0.0727
# Epoch 26 Batch 1000 Loss 0.0643
# Epoch 26 Batch 1100 Loss 0.0690
# Epoch 26 Batch 1200 Loss 0.0325
# Epoch 26 Loss 0.0548
# Time taken for 1 epoch 119.67245697975159 sec
#
# Epoch 27 Batch 0 Loss 0.0448
# Epoch 27 Batch 100 Loss 0.0233
# Epoch 27 Batch 200 Loss 0.0414
# Epoch 27 Batch 300 Loss 0.0453
# Epoch 27 Batch 400 Loss 0.0234
# Epoch 27 Batch 500 Loss 0.0616
# Epoch 27 Batch 600 Loss 0.0492
# Epoch 27 Batch 700 Loss 0.0448
# Epoch 27 Batch 800 Loss 0.0416
# Epoch 27 Batch 900 Loss 0.0725
# Epoch 27 Batch 1000 Loss 0.0633
# Epoch 27 Batch 1100 Loss 0.0331
# Epoch 27 Batch 1200 Loss 0.0746
# Epoch 27 Loss 0.0540
# Time taken for 1 epoch 120.02358412742615 sec
#
# Epoch 28 Batch 0 Loss 0.0423
# Epoch 28 Batch 100 Loss 0.0429
# Epoch 28 Batch 200 Loss 0.0318
# Epoch 28 Batch 300 Loss 0.0417
# Epoch 28 Batch 400 Loss 0.0653
# Epoch 28 Batch 500 Loss 0.0332
# Epoch 28 Batch 600 Loss 0.0546
# Epoch 28 Batch 700 Loss 0.0842
# Epoch 28 Batch 800 Loss 0.0501
# Epoch 28 Batch 900 Loss 0.0423
# Epoch 28 Batch 1000 Loss 0.0400
# Epoch 28 Batch 1100 Loss 0.0525
# Epoch 28 Batch 1200 Loss 0.0570
# Epoch 28 Loss 0.0531
# Time taken for 1 epoch 120.88695287704468 sec
#
# Epoch 29 Batch 0 Loss 0.0673
# Epoch 29 Batch 100 Loss 0.0399
# Epoch 29 Batch 200 Loss 0.0498
# Epoch 29 Batch 300 Loss 0.0799
# Epoch 29 Batch 400 Loss 0.0453
# Epoch 29 Batch 500 Loss 0.0519
# Epoch 29 Batch 600 Loss 0.0369
# Epoch 29 Batch 700 Loss 0.0651
# Epoch 29 Batch 800 Loss 0.0222
# Epoch 29 Batch 900 Loss 0.0488
# Epoch 29 Batch 1000 Loss 0.0837
# Epoch 29 Batch 1100 Loss 0.0578
# Epoch 29 Batch 1200 Loss 0.0433
# Epoch 29 Loss 0.0527
# Time taken for 1 epoch 119.70960879325867 sec
#
# Epoch 30 Batch 0 Loss 0.0309
# Epoch 30 Batch 100 Loss 0.0426
# Epoch 30 Batch 200 Loss 0.0707
# Epoch 30 Batch 300 Loss 0.0692
# Epoch 30 Batch 400 Loss 0.0311
# Epoch 30 Batch 500 Loss 0.0381
# Epoch 30 Batch 600 Loss 0.0306
# Epoch 30 Batch 700 Loss 0.0358
# Epoch 30 Batch 800 Loss 0.0321
# Epoch 30 Batch 900 Loss 0.0633
# Epoch 30 Batch 1000 Loss 0.0814
# Epoch 30 Batch 1100 Loss 0.1052
# Epoch 30 Batch 1200 Loss 0.1018
# Epoch 30 Loss 0.0526
# Time taken for 1 epoch 118.56288409233093 sec
#
# Epoch 31 Batch 0 Loss 0.0391
# Epoch 31 Batch 100 Loss 0.0426
# Epoch 31 Batch 200 Loss 0.0295
# Epoch 31 Batch 300 Loss 0.0571
# Epoch 31 Batch 400 Loss 0.0630
# Epoch 31 Batch 500 Loss 0.0492
# Epoch 31 Batch 600 Loss 0.0391
# Epoch 31 Batch 700 Loss 0.0826
# Epoch 31 Batch 800 Loss 0.0554
# Epoch 31 Batch 900 Loss 0.0491
# Epoch 31 Batch 1000 Loss 0.0819
# Epoch 31 Batch 1100 Loss 0.0373
# Epoch 31 Batch 1200 Loss 0.0487
# Epoch 31 Loss 0.0513
# Time taken for 1 epoch 120.37365078926086 sec
#
# Epoch 32 Batch 0 Loss 0.0481
# Epoch 32 Batch 100 Loss 0.0450
# Epoch 32 Batch 200 Loss 0.0435
# Epoch 32 Batch 300 Loss 0.0504
# Epoch 32 Batch 400 Loss 0.0673
# Epoch 32 Batch 500 Loss 0.0484
# Epoch 32 Batch 600 Loss 0.0443
# Epoch 32 Batch 700 Loss 0.0635
# Epoch 32 Batch 800 Loss 0.0440
# Epoch 32 Batch 900 Loss 0.0463
# Epoch 32 Batch 1000 Loss 0.0494
# Epoch 32 Batch 1100 Loss 0.0816
# Epoch 32 Batch 1200 Loss 0.0858
# Epoch 32 Loss 0.0508
# Time taken for 1 epoch 121.60156750679016 sec
#
# Epoch 33 Batch 0 Loss 0.0308
# Epoch 33 Batch 100 Loss 0.0490
# Epoch 33 Batch 200 Loss 0.0321
# Epoch 33 Batch 300 Loss 0.0351
# Epoch 33 Batch 400 Loss 0.0801
# Epoch 33 Batch 500 Loss 0.0414
# Epoch 33 Batch 600 Loss 0.0387
# Epoch 33 Batch 700 Loss 0.0508
# Epoch 33 Batch 800 Loss 0.0668
# Epoch 33 Batch 900 Loss 0.0734
# Epoch 33 Batch 1000 Loss 0.0256
# Epoch 33 Batch 1100 Loss 0.0532
# Epoch 33 Batch 1200 Loss 0.0513
# Epoch 33 Loss 0.0502
# Time taken for 1 epoch 121.36798572540283 sec
#
# Epoch 34 Batch 0 Loss 0.0188
# Epoch 34 Batch 100 Loss 0.0271
# Epoch 34 Batch 200 Loss 0.0304
# Epoch 34 Batch 300 Loss 0.0238
# Epoch 34 Batch 400 Loss 0.0213
# Epoch 34 Batch 500 Loss 0.0460
# Epoch 34 Batch 600 Loss 0.0827
# Epoch 34 Batch 700 Loss 0.0481
# Epoch 34 Batch 800 Loss 0.0604
# Epoch 34 Batch 900 Loss 0.0429
# Epoch 34 Batch 1000 Loss 0.0469
# Epoch 34 Batch 1100 Loss 0.1007
# Epoch 34 Batch 1200 Loss 0.0801
# Epoch 34 Loss 0.0499
# Time taken for 1 epoch 122.05416345596313 sec
#
# Epoch 35 Batch 0 Loss 0.0406
# Epoch 35 Batch 100 Loss 0.0394
# Epoch 35 Batch 200 Loss 0.0193
# Epoch 35 Batch 300 Loss 0.0705
# Epoch 35 Batch 400 Loss 0.0397
# Epoch 35 Batch 500 Loss 0.0629
# Epoch 35 Batch 600 Loss 0.0585
# Epoch 35 Batch 700 Loss 0.0457
# Epoch 35 Batch 800 Loss 0.0352
# Epoch 35 Batch 900 Loss 0.0468
# Epoch 35 Batch 1000 Loss 0.0538
# Epoch 35 Batch 1100 Loss 0.0419
# Epoch 35 Batch 1200 Loss 0.0634
# Epoch 35 Loss 0.0490
# Time taken for 1 epoch 121.15473937988281 sec
#
# Epoch 36 Batch 0 Loss 0.0188
# Epoch 36 Batch 100 Loss 0.0378
# Epoch 36 Batch 200 Loss 0.0387
# Epoch 36 Batch 300 Loss 0.0768
# Epoch 36 Batch 400 Loss 0.0538
# Epoch 36 Batch 500 Loss 0.0375
# Epoch 36 Batch 600 Loss 0.0547
# Epoch 36 Batch 700 Loss 0.0668
# Epoch 36 Batch 800 Loss 0.0596
# Epoch 36 Batch 900 Loss 0.0879
# Epoch 36 Batch 1000 Loss 0.0366
# Epoch 36 Batch 1100 Loss 0.0509
# Epoch 36 Batch 1200 Loss 0.0832
# Epoch 36 Loss 0.0489
# Time taken for 1 epoch 121.9806056022644 sec
#
# Epoch 37 Batch 0 Loss 0.0497
# Epoch 37 Batch 100 Loss 0.0493
# Epoch 37 Batch 200 Loss 0.0384
# Epoch 37 Batch 300 Loss 0.0537
# Epoch 37 Batch 400 Loss 0.0542
# Epoch 37 Batch 500 Loss 0.0526
# Epoch 37 Batch 600 Loss 0.0231
# Epoch 37 Batch 700 Loss 0.0747
# Epoch 37 Batch 800 Loss 0.0332
# Epoch 37 Batch 900 Loss 0.0621
# Epoch 37 Batch 1000 Loss 0.0443
# Epoch 37 Batch 1100 Loss 0.0476
# Epoch 37 Batch 1200 Loss 0.0485
# Epoch 37 Loss 0.0484
# Time taken for 1 epoch 121.51866173744202 sec
#
# Epoch 38 Batch 0 Loss 0.0162
# Epoch 38 Batch 100 Loss 0.0241
# Epoch 38 Batch 200 Loss 0.0205
# Epoch 38 Batch 300 Loss 0.0407
# Epoch 38 Batch 400 Loss 0.0322
# Epoch 38 Batch 500 Loss 0.0341
# Epoch 38 Batch 600 Loss 0.0370
# Epoch 38 Batch 700 Loss 0.0521
# Epoch 38 Batch 800 Loss 0.0545
# Epoch 38 Batch 900 Loss 0.0413
# Epoch 38 Batch 1000 Loss 0.0206
# Epoch 38 Batch 1100 Loss 0.0431
# Epoch 38 Batch 1200 Loss 0.0367
# Epoch 38 Loss 0.0476
# Time taken for 1 epoch 121.95102214813232 sec
#
# Epoch 39 Batch 0 Loss 0.0236
# Epoch 39 Batch 100 Loss 0.0140
# Epoch 39 Batch 200 Loss 0.0411
# Epoch 39 Batch 300 Loss 0.0322
# Epoch 39 Batch 400 Loss 0.0557
# Epoch 39 Batch 500 Loss 0.0370
# Epoch 39 Batch 600 Loss 0.0427
# Epoch 39 Batch 700 Loss 0.0295
# Epoch 39 Batch 800 Loss 0.0540
# Epoch 39 Batch 900 Loss 0.0314
# Epoch 39 Batch 1000 Loss 0.0604
# Epoch 39 Batch 1100 Loss 0.0799
# Epoch 39 Batch 1200 Loss 0.0706
# Epoch 39 Loss 0.0475
# Time taken for 1 epoch 121.93810844421387 sec
#
# Epoch 40 Batch 0 Loss 0.0172
# Epoch 40 Batch 100 Loss 0.0305
# Epoch 40 Batch 200 Loss 0.0360
# Epoch 40 Batch 300 Loss 0.0396
# Epoch 40 Batch 400 Loss 0.0354
# Epoch 40 Batch 500 Loss 0.0670
# Epoch 40 Batch 600 Loss 0.0564
# Epoch 40 Batch 700 Loss 0.0642
# Epoch 40 Batch 800 Loss 0.0474
# Epoch 40 Batch 900 Loss 0.0240
# Epoch 40 Batch 1000 Loss 0.0526
# Epoch 40 Batch 1100 Loss 0.0541
# Epoch 40 Batch 1200 Loss 0.0579
# Epoch 40 Loss 0.0469
# Time taken for 1 epoch 123.16926646232605 sec
#
# Epoch 41 Batch 0 Loss 0.0291
# Epoch 41 Batch 100 Loss 0.0321
# Epoch 41 Batch 200 Loss 0.0540
# Epoch 41 Batch 300 Loss 0.0396
# Epoch 41 Batch 400 Loss 0.0481
# Epoch 41 Batch 500 Loss 0.0593
# Epoch 41 Batch 600 Loss 0.0514
# Epoch 41 Batch 700 Loss 0.0505
# Epoch 41 Batch 800 Loss 0.0503
# Epoch 41 Batch 900 Loss 0.0652
# Epoch 41 Batch 1000 Loss 0.0482
# Epoch 41 Batch 1100 Loss 0.0310
# Epoch 41 Batch 1200 Loss 0.0468
# Epoch 41 Loss 0.0463
# Time taken for 1 epoch 121.94275498390198 sec
#
# Epoch 42 Batch 0 Loss 0.0352
# Epoch 42 Batch 100 Loss 0.0267
# Epoch 42 Batch 200 Loss 0.0409
# Epoch 42 Batch 300 Loss 0.0219
# Epoch 42 Batch 400 Loss 0.0409
# Epoch 42 Batch 500 Loss 0.0706
# Epoch 42 Batch 600 Loss 0.0323
# Epoch 42 Batch 700 Loss 0.0364
# Epoch 42 Batch 800 Loss 0.0445
# Epoch 42 Batch 900 Loss 0.0474
# Epoch 42 Batch 1000 Loss 0.0445
# Epoch 42 Batch 1100 Loss 0.0552
# Epoch 42 Batch 1200 Loss 0.0338
# Epoch 42 Loss 0.0460
# Time taken for 1 epoch 122.45324110984802 sec
#
# Epoch 43 Batch 0 Loss 0.0509
# Epoch 43 Batch 100 Loss 0.0483
# Epoch 43 Batch 200 Loss 0.0226
# Epoch 43 Batch 300 Loss 0.0466
# Epoch 43 Batch 400 Loss 0.0305
# Epoch 43 Batch 500 Loss 0.0321
# Epoch 43 Batch 600 Loss 0.0430
# Epoch 43 Batch 700 Loss 0.0376
# Epoch 43 Batch 800 Loss 0.0372
# Epoch 43 Batch 900 Loss 0.0480
# Epoch 43 Batch 1000 Loss 0.0391
# Epoch 43 Batch 1100 Loss 0.0705
# Epoch 43 Batch 1200 Loss 0.0377
# Epoch 43 Loss 0.0460
# Time taken for 1 epoch 121.86974239349365 sec
#
# Epoch 44 Batch 0 Loss 0.0502
# Epoch 44 Batch 100 Loss 0.0317
# Epoch 44 Batch 200 Loss 0.0252
# Epoch 44 Batch 300 Loss 0.0413
# Epoch 44 Batch 400 Loss 0.0620
# Epoch 44 Batch 500 Loss 0.0511
# Epoch 44 Batch 600 Loss 0.0738
# Epoch 44 Batch 700 Loss 0.0634
# Epoch 44 Batch 800 Loss 0.0494
# Epoch 44 Batch 900 Loss 0.0554
# Epoch 44 Batch 1000 Loss 0.0495
# Epoch 44 Batch 1100 Loss 0.0793
# Epoch 44 Batch 1200 Loss 0.0853
# Epoch 44 Loss 0.0450
# Time taken for 1 epoch 121.99962854385376 sec
#
# Epoch 45 Batch 0 Loss 0.0457
# Epoch 45 Batch 100 Loss 0.0269
# Epoch 45 Batch 200 Loss 0.0312
# Epoch 45 Batch 300 Loss 0.0398
# Epoch 45 Batch 400 Loss 0.0658
# Epoch 45 Batch 500 Loss 0.0372
# Epoch 45 Batch 600 Loss 0.0530
# Epoch 45 Batch 700 Loss 0.0301
# Epoch 45 Batch 800 Loss 0.0437
# Epoch 45 Batch 900 Loss 0.0445
# Epoch 45 Batch 1000 Loss 0.0640
# Epoch 45 Batch 1100 Loss 0.0753
# Epoch 45 Batch 1200 Loss 0.0614
# Epoch 45 Loss 0.0448
# Time taken for 1 epoch 123.18382549285889 sec
#
# Epoch 46 Batch 0 Loss 0.0441
# Epoch 46 Batch 100 Loss 0.0393
# Epoch 46 Batch 200 Loss 0.0141
# Epoch 46 Batch 300 Loss 0.0360
# Epoch 46 Batch 400 Loss 0.0404
# Epoch 46 Batch 500 Loss 0.0254
# Epoch 46 Batch 600 Loss 0.0406
# Epoch 46 Batch 700 Loss 0.0261
# Epoch 46 Batch 800 Loss 0.0455
# Epoch 46 Batch 900 Loss 0.0245
# Epoch 46 Batch 1000 Loss 0.0597
# Epoch 46 Batch 1100 Loss 0.0619
# Epoch 46 Batch 1200 Loss 0.0727
# Epoch 46 Loss 0.0445
# Time taken for 1 epoch 121.43737697601318 sec
#
# Epoch 47 Batch 0 Loss 0.0314
# Epoch 47 Batch 100 Loss 0.0316
# Epoch 47 Batch 200 Loss 0.0482
# Epoch 47 Batch 300 Loss 0.0312
# Epoch 47 Batch 400 Loss 0.0413
# Epoch 47 Batch 500 Loss 0.0279
# Epoch 47 Batch 600 Loss 0.0202
# Epoch 47 Batch 700 Loss 0.0305
# Epoch 47 Batch 800 Loss 0.0322
# Epoch 47 Batch 900 Loss 0.0413
# Epoch 47 Batch 1000 Loss 0.0678
# Epoch 47 Batch 1100 Loss 0.0663
# Epoch 47 Batch 1200 Loss 0.0413
# Epoch 47 Loss 0.0440
# Time taken for 1 epoch 118.8705575466156 sec
#
# Epoch 48 Batch 0 Loss 0.0210
# Epoch 48 Batch 100 Loss 0.0156
# Epoch 48 Batch 200 Loss 0.0233
# Epoch 48 Batch 300 Loss 0.0470
# Epoch 48 Batch 400 Loss 0.0151
# Epoch 48 Batch 500 Loss 0.0577
# Epoch 48 Batch 600 Loss 0.0446
# Epoch 48 Batch 700 Loss 0.0222
# Epoch 48 Batch 800 Loss 0.0266
# Epoch 48 Batch 900 Loss 0.0313
# Epoch 48 Batch 1000 Loss 0.0484
# Epoch 48 Batch 1100 Loss 0.0842
# Epoch 48 Batch 1200 Loss 0.0785
# Epoch 48 Loss 0.0443
# Time taken for 1 epoch 119.18634510040283 sec
#
# Epoch 49 Batch 0 Loss 0.0381
# Epoch 49 Batch 100 Loss 0.0471
# Epoch 49 Batch 200 Loss 0.0191
# Epoch 49 Batch 300 Loss 0.0220
# Epoch 49 Batch 400 Loss 0.0327
# Epoch 49 Batch 500 Loss 0.0443
# Epoch 49 Batch 600 Loss 0.0499
# Epoch 49 Batch 700 Loss 0.0171
# Epoch 49 Batch 800 Loss 0.0668
# Epoch 49 Batch 900 Loss 0.0464
# Epoch 49 Batch 1000 Loss 0.0427
# Epoch 49 Batch 1100 Loss 0.0547
# Epoch 49 Batch 1200 Loss 0.0412
# Epoch 49 Loss 0.0436
# Time taken for 1 epoch 120.17469954490662 sec
#
# Epoch 50 Batch 0 Loss 0.0279
# Epoch 50 Batch 100 Loss 0.0383
# Epoch 50 Batch 200 Loss 0.0457
# Epoch 50 Batch 300 Loss 0.0436
# Epoch 50 Batch 400 Loss 0.0377
# Epoch 50 Batch 500 Loss 0.0242
# Epoch 50 Batch 600 Loss 0.0499
# Epoch 50 Batch 700 Loss 0.0289
# Epoch 50 Batch 800 Loss 0.0652
# Epoch 50 Batch 900 Loss 0.0487
# Epoch 50 Batch 1000 Loss 0.0493
# Epoch 50 Batch 1100 Loss 0.0327
# Epoch 50 Batch 1200 Loss 0.0668
# Epoch 50 Loss 0.0433
# Time taken for 1 epoch 117.88583540916443 sec

# %% [markdown]
# ## Translate
#
# * The evaluate function is similar to the training loop, except we don't use *teacher forcing* here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# * Stop predicting when the model predicts the *end token*.
# * And store the *attention weights for every time step*.
#
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, dec_hidden)

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: india vicious plans meteor receipt princess princess teasing teasing flaws avocados

# %%
translate('Я не смогу поехать.')
# Out:
# Input: <start> я не смогу поехать . <end>
# Predicted translation: india vicious plans meteor receipt princess princess teasing teasing flaws avocados

# %%
translate(u'Вы еще дома?')
# Out:
# Input: <start> вы еще дома ? <end>
# Predicted translation: are you home alone ? <end>

# %%
translate(u'Вы все еще дома?')
# Out:
# Input: <start> вы все еще дома ? <end>
# Predicted translation: can you still home ? <end>

# %%
translate(u'Попробуй сделать это.')
# Out:
# Input: <start> попробуй сделать это . <end>
# Predicted translation: try to do that . <end>

# %%
translate(u'Я люблю, когда идет снег.')
# Out:
# Input: <start> я люблю , когда идет снег . <end>
# Predicted translation: i love how it will . <end>

# %%
translate(u'Я никогда такого не делаю.')
# Out:
# Input: <start> я никогда такого не делаю . <end>
# Predicted translation: i never do that . <end>
