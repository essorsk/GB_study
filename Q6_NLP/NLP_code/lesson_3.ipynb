# %% [markdown]
# # Word2vec & Fasttext

# %% [markdown]
# Есть 2 режима обучения word2vec:
# - cbow
# - skipgram

# %% [markdown]
# <img src='image/w2v.png'>

# %% [markdown]
# Fasttext работает +- также как word2vec, только включает в вектор слова еще n-gramm побуквенные.
#
# <img src='image/ft.png'>

# %% [markdown]
# Важно помнить, что энграммы хешируются -> маленькое число бакетов -> просад по качеству

# %% [markdown]
# # Тематическое моделирование
#
# <img src='image/tm.webp'>

# %%
import re
import numpy as np
import pandas as pd
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt
# %matplotlib inline
from nltk.corpus import stopwords


df = pd.read_json('https://raw.githubusercontent.com/selva86/datasets/master/newsgroups.json')
print(df.target_names.unique())
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
# Out:
# ['rec.autos' 'comp.sys.mac.hardware' 'comp.graphics' 'sci.space'
#  'talk.politics.guns' 'sci.med' 'comp.sys.ibm.pc.hardware'
#  'comp.os.ms-windows.misc' 'rec.motorcycles' 'talk.religion.misc'
#  'misc.forsale' 'alt.atheism' 'sci.electronics' 'comp.windows.x'
#  'rec.sport.hockey' 'rec.sport.baseball' 'soc.religion.christian'
#  'talk.politics.mideast' 'talk.politics.misc' 'sci.crypt']

# %%
df['content'][0]
# Out:
# "From: lerxst@wam.umd.edu (where's my thing)\nSubject: WHAT car is this!?\nNntp-Posting-Host: rac3.wam.umd.edu\nOrganization: University of Maryland, College Park\nLines: 15\n\n I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.\n\nThanks,\n- IL\n   ---- brought to you by your neighborhood Lerxst ----\n\n\n\n\n"

# %%
data = df.content.values.tolist()

data = [re.sub('\S*@\S*\s?', '', sent) for sent in data]
data = [re.sub('\s+', ' ', sent) for sent in data]
data = [re.sub("\'", "", sent) for sent in data]

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

data_words = list(sent_to_words(data))
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100)
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['from', 'wheres', 'my', 'thing', 'subject', 'what', 'car', 'is', 'this', 'nntp_posting_host', 'rac_wam_umd_edu', 'organization', 'university', 'of', 'maryland_college_park', 'lines', 'was', 'wondering', 'if', 'anyone', 'out', 'there', 'could', 'enlighten', 'me', 'on', 'this', 'car', 'saw', 'the', 'other', 'day', 'it', 'was', 'door', 'sports', 'car', 'looked', 'to', 'be', 'from', 'the', 'late', 'early', 'it', 'was', 'called', 'bricklin', 'the', 'doors', 'were', 'really', 'small', 'in', 'addition', 'the', 'front_bumper', 'was', 'separate', 'from', 'the', 'rest', 'of', 'the', 'body', 'this', 'is', 'all', 'know', 'if', 'anyone', 'can', 'tellme', 'model', 'name', 'engine', 'specs', 'years', 'of', 'production', 'where', 'this', 'car', 'is', 'made', 'history', 'or', 'whatever', 'info', 'you', 'have', 'on', 'this', 'funky', 'looking', 'car', 'please', 'mail', 'thanks', 'il', 'brought', 'to', 'you', 'by', 'your', 'neighborhood', 'lerxst']

# %%
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

# %%
data_words_nostops = remove_stopwords(data_words)
data_words_bigrams = make_bigrams(data_words_nostops)

# %%
data_words_bigrams[2]
# Out:
# ['thomas',
#  'willis',
#  'pb',
#  'questions',
#  'organization',
#  'purdue_university',
#  'engineering',
#  'computer',
#  'network',
#  'distribution_usa',
#  'lines',
#  'well',
#  'folks',
#  'mac',
#  'plus',
#  'finally',
#  'gave',
#  'ghost',
#  'weekend',
#  'starting',
#  'life',
#  'way',
#  'back',
#  'sooo',
#  'im',
#  'market',
#  'new',
#  'machine',
#  'bit',
#  'sooner',
#  'intended',
#  'im',
#  'looking',
#  'picking',
#  'powerbook',
#  'maybe',
#  'bunch',
#  'questions',
#  'hopefully',
#  'somebody',
#  'answer',
#  'anybody',
#  'know',
#  'dirt',
#  'next',
#  'round',
#  'powerbook',
#  'introductions',
#  'expected',
#  'id',
#  'heard',
#  'supposed',
#  'make',
#  'appearence',
#  'summer',
#  'havent',
#  'heard',
#  'anymore',
#  'since',
#  'dont',
#  'access',
#  'macleak',
#  'wondering',
#  'anybody',
#  'info',
#  'anybody',
#  'heard',
#  'rumors',
#  'price',
#  'drops',
#  'powerbook',
#  'line',
#  'like',
#  'ones',
#  'duos',
#  'went',
#  'recently',
#  'whats',
#  'impression',
#  'display',
#  'could',
#  'probably',
#  'swing',
#  'got',
#  'mb',
#  'disk',
#  'rather',
#  'dont',
#  'really',
#  'feel',
#  'much',
#  'better',
#  'display',
#  'yea',
#  'looks',
#  'great',
#  'store',
#  'wow',
#  'really',
#  'good',
#  'could',
#  'solicit',
#  'opinions',
#  'people',
#  'day',
#  'day',
#  'worth',
#  'taking',
#  'disk',
#  'size',
#  'money',
#  'hit',
#  'get',
#  'active',
#  'display',
#  'realize',
#  'real',
#  'subjective',
#  'question',
#  'ive',
#  'played',
#  'around',
#  'machines',
#  'computer',
#  'store',
#  'breifly',
#  'figured',
#  'opinions',
#  'somebody',
#  'actually',
#  'uses',
#  'machine',
#  'daily',
#  'might',
#  'prove',
#  'helpful',
#  'well',
#  'hellcats',
#  'perform',
#  'thanks',
#  'bunch',
#  'advance',
#  'info',
#  'could',
#  'email',
#  'ill',
#  'post',
#  'summary',
#  'news',
#  'reading',
#  'time',
#  'premium',
#  'finals',
#  'around',
#  'corner',
#  'tom',
#  'willis',
#  'purdue',
#  'electrical_engineering',
#  'convictions',
#  'dangerous_enemies',
#  'truth',
#  'lies',
#  'nietzsche']

# %%
id2word = corpora.Dictionary(data_words_bigrams)
texts = data_words_bigrams
corpus = [id2word.doc2bow(text) for text in texts]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=1,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
print(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0, '0.079*"jesus" + 0.079*"faith" + 0.079*"god" + 0.064*"christians" + 0.059*"bible" + 0.045*"christian" + 0.038*"church" + 0.029*"christ" + 0.014*"indeed" + 0.013*"jewish"'), (1, '0.050*"newsreader_tin" + 0.042*"self" + 0.039*"la" + 0.039*"version_pl" + 0.034*"motif" + 0.031*"al" + 0.017*"blue" + 0.017*"helmet" + 0.016*"activity" + 0.014*"levels"'), (2, '0.010*"time" + 0.009*"us" + 0.008*"may" + 0.008*"first" + 0.007*"two" + 0.007*"help" + 0.006*"day" + 0.006*"said" + 0.005*"new" + 0.005*"one"'), (3, '0.060*"senses" + 0.031*"bike" + 0.026*"speak" + 0.024*"engine" + 0.019*"dod" + 0.018*"power" + 0.017*"picture" + 0.015*"stolen" + 0.015*"disagree" + 0.011*"owner"'), (4, '0.112*"physical" + 0.031*"dc" + 0.031*"direct" + 0.021*"ac" + 0.018*"oo" + 0.018*"ab" + 0.018*"gov" + 0.017*"spacecraft" + 0.016*"vms_vnews" + 0.016*"software_vax"'), (5, '0.050*"team" + 0.045*"game" + 0.036*"sale" + 0.030*"year" + 0.027*"games" + 0.026*"points" + 0.023*"win" + 0.022*"teams" + 0.021*"color" + 0.021*"play"'), (6, '0.042*"key" + 0.018*"system" + 0.016*"israel" + 0.016*"distribution_na" + 0.015*"keys" + 0.014*"master" + 0.014*"encryption" + 0.014*"mr" + 0.014*"security" + 0.013*"public"'), (7, '0.693*"ax" + 0.056*"max" + 0.011*"el" + 0.010*"mu" + 0.008*"saturn" + 0.006*"mr" + 0.006*"rt" + 0.005*"vw" + 0.004*"ft" + 0.003*"gt"'), (8, '0.027*"lines" + 0.026*"organization" + 0.017*"writes" + 0.016*"article" + 0.015*"would" + 0.014*"like" + 0.013*"one" + 0.011*"nntp_posting" + 0.011*"dont" + 0.011*"know"'), (9, '0.020*"israel" + 0.015*"war" + 0.014*"soldiers" + 0.013*"israeli" + 0.013*"jews" + 0.012*"killed" + 0.011*"people" + 0.011*"said" + 0.010*"women" + 0.010*"government"'), (10, '0.085*"space" + 0.029*"research" + 0.028*"patient" + 0.027*"talking" + 0.024*"die" + 0.023*"health" + 0.020*"nasa" + 0.018*"ground" + 0.017*"patients" + 0.017*"orbit"'), (11, '0.026*"people" + 0.018*"god" + 0.017*"evidence" + 0.013*"believe" + 0.013*"reason" + 0.012*"one" + 0.012*"would" + 0.011*"say" + 0.011*"us" + 0.010*"think"'), (12, '0.026*"system" + 0.024*"drive" + 0.017*"software" + 0.016*"data" + 0.014*"card" + 0.014*"mac" + 0.013*"computer" + 0.013*"using" + 0.012*"cpu" + 0.012*"mb"'), (13, '0.026*"faq" + 0.020*"events" + 0.018*"function" + 0.015*"mit" + 0.011*"ice" + 0.011*"joseph" + 0.010*"ltd" + 0.010*"object" + 0.010*"copies" + 0.010*"terms"'), (14, '0.035*"switch" + 0.028*"nec" + 0.024*"mw" + 0.020*"cable" + 0.019*"pack" + 0.017*"finland" + 0.016*"cap" + 0.014*"circuits" + 0.013*"sgi" + 0.013*"bj"'), (15, '0.062*"rsa" + 0.039*"update" + 0.026*"load" + 0.015*"allen" + 0.012*"mets" + 0.011*"ms_windows" + 0.009*"ratio" + 0.009*"click" + 0.007*"eff" + 0.006*"maryland_college"'), (16, '0.066*"pin" + 0.044*"disk" + 0.044*"telnet" + 0.040*"period" + 0.031*"processor" + 0.022*"kevin" + 0.021*"doug" + 0.018*"ns" + 0.014*"configuration" + 0.012*"fl"'), (17, '0.052*"windows" + 0.042*"file" + 0.032*"files" + 0.029*"program" + 0.026*"dos" + 0.025*"graphics" + 0.025*"entry" + 0.021*"md" + 0.020*"window" + 0.017*"unix"'), (18, '0.026*"st" + 0.025*"season" + 0.021*"vs" + 0.021*"scott" + 0.019*"wings" + 0.018*"dave" + 0.018*"boston" + 0.017*"ed" + 0.016*"em" + 0.016*"van"'), (19, '0.039*"government" + 0.032*"public" + 0.030*"gun" + 0.020*"state" + 0.019*"president" + 0.019*"guns" + 0.015*"clinton" + 0.014*"rights" + 0.012*"crime" + 0.012*"safety"')]

# %% [markdown]
# ## Тема 3. Разметка и извлечение именованных сущностей

# %% [markdown]
# ### 3.1. Разметка слов с помощью частей речи (Parts-Of-Speech)

# %% [markdown]
# <img src='image/pos_tagging.PNG'>

# %% [markdown]
# POS разметка - определение части речи и грамматических характеристик слов в тексте (корпусе) с приписыванием им соответствующих тегов. POS tagging является одним из первых этапов компьютерного анализа текста. Эта задача не простая, так как конкретное слово может иметь различную часть речи в зависимости от контекста, в котором оно используется.
# Например: в предложении “Дай мне свой ответ” ответ - это существительное, а в предложении “ответь на вопрос” ответ - это глагол.
#
# POS разметка полезна для построения деревьев синтаксического анализа, которые используются при построении NER (именованных сущностей) и извлечении отношений между словами. POS-маркировка также необходима для построения лемматизаторов.

# %%
#nltk.download() 
import nltk
from nltk.tokenize import word_tokenize
import matplotlib
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Универсальный набор тегов части речи

# %% [markdown]
# Ниже приведена таблица POS-тэгов: обозначение, часть речи, пример. Цветом выделены популярные части речи: существительное, глагол и вопросительное слово.

# %% [markdown]
# <img src='image/pos_tag_samples.jpg'>

# %% [markdown]
# Выведим примеры тэгов разных частей речи.

# %%
import nltk
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\essor\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping help\tagsets.zip.
# True

# %%
nltk.help.upenn_tagset('RB')
nltk.help.upenn_tagset('NN')
nltk.help.upenn_tagset('VB')
# Out:
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...

# %% [markdown]
# #### Сравнение POS тэггеров

# %% [markdown]
# POS-тэггер обрабатывает последовательность слов и определяет тэг части речи для каждого слова. Сравним работу нескольких тэггеров библиотеки nltk.tag. Проверять работоспособность теггеров будем на корпусе nltk.corpus.brown.
#
# Отобразим распределение тэгов в корпусе brown. Можем видеть, что тэг "NN" наиболее популярный.
#
# Корпус будет поделен на train и test, т.к. некоторым тэггерам необходимо обучение. Разметку визуально будем оценивать на примере test_sent, тестового предложения.

# %%
import nltk

# %%
nltk.corpus
# Out:
# <LazyModule 'nltk.corpus'>

# %%
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\essor\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# True

# %%
from nltk.corpus import brown
from nltk.tag import DefaultTagger
from nltk.tag import UnigramTagger
from nltk.tag import BigramTagger, TrigramTagger
from nltk.tag import RegexpTagger

tags = [tag for (word, tag) in
brown.tagged_words(categories='news')]
nltk.FreqDist(tags)
# Out:
# FreqDist({'NN': 13162, 'IN': 10616, 'AT': 8893, 'NP': 6866, ',': 5133, 'NNS': 5066, '.': 4452, 'JJ': 4392, 'CC': 2664, 'VBD': 2524, ...})

# %%
brown_tagged_sents = brown.tagged_sents(categories='news')
train_data = brown_tagged_sents[:int(len(brown_tagged_sents) * 0.9)]
test_data = brown_tagged_sents[int(len(brown_tagged_sents) * 0.9):]
test_sent = brown.sents(categories='news')[0]
test_data[0]
# Out:
# [('But', 'CC'),
#  ('in', 'IN'),
#  ('all', 'ABN'),
#  ('its', 'PP$'),
#  ('175', 'CD'),
#  ('years', 'NNS'),
#  (',', ','),
#  ('not', '*'),
#  ('a', 'AT'),
#  ('single', 'AP'),
#  ('Negro', 'NP'),
#  ('student', 'NN'),
#  ('has', 'HVZ'),
#  ('entered', 'VBN'),
#  ('its', 'PP$'),
#  ('classrooms', 'NNS'),
#  ('.', '.')]

# %% [markdown]
# #### DefaultTagger
#
# Очень наивный тэггер, в данном случае присваивает тэг "NN" (noun) всем словам в тексте. Т.к. в английском тексте примерно 13% сущесвительных, то получим точность тэггирования примерно 0,13.
#
# У каждого теггера есть метод .tag(), который принимает список токенов (обычно список слов, созданных токенизатором слов), где каждый токен-это одно слово.
# Метод .evaluate() оценивает точность работы тэггера.

# %%
default_tagger = nltk.DefaultTagger('NN')
display(default_tagger.tag(test_sent), default_tagger.evaluate(test_data))
# Out:
# [('The', 'NN'),
#  ('Fulton', 'NN'),
#  ('County', 'NN'),
#  ('Grand', 'NN'),
#  ('Jury', 'NN'),
#  ('said', 'NN'),
#  ('Friday', 'NN'),
#  ('an', 'NN'),
#  ('investigation', 'NN'),
#  ('of', 'NN'),
#  ("Atlanta's", 'NN'),
#  ('recent', 'NN'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'NN'),
#  ('``', 'NN'),
#  ('no', 'NN'),
#  ('evidence', 'NN'),
#  ("''", 'NN'),
#  ('that', 'NN'),
#  ('any', 'NN'),
#  ('irregularities', 'NN'),
#  ('took', 'NN'),
#  ('place', 'NN'),
#  ('.', 'NN')]
# 0.1262832652247583

# %% [markdown]
# #### UnigramTagger
#
# UnigramTagger учитывает условную частоту тегов и предсказывает наиболее частый тег для каждого токена, не ориентируется на соседние слова.

# %%
unigram_tagger = UnigramTagger(train_data)
display(unigram_tagger.tag(test_sent), unigram_tagger.evaluate(test_data))
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.')]
# 0.8121200039868434

# %% [markdown]
# #### BigramTagger
#
# BigramTagger будет учитывает тэги двух слов: текущее и предыдущее слово. Точность немного выше, чем у Unigram tagger.

# %%
bigram_tagger = BigramTagger(train_data, backoff=unigram_tagger)
display(bigram_tagger.tag(test_sent), bigram_tagger.evaluate(test_data))
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.')]
# 0.8210904016744742

# %% [markdown]
# #### TrigramTagger

# %%
trigram_tagger = TrigramTagger(train_data, backoff=bigram_tagger)
display(trigram_tagger.tag(test_sent), trigram_tagger.evaluate(test_data))
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.')]
# 0.8185986245390212

# %% [markdown]
# #### RegexpTagger

# %% [markdown]
# RegexpTagger работает на основе поиска совпаднения с регулярными выражениями. Пример: числа можно сопоставить с регулярным выражением "\d" для присвоения тега CD (Cardinal number) или можно сопоставить известные шаблоны слов, такие как суффикс '.*ing$'.

# %%
patterns = [
    (r'.*ing$', 'VBG'),                # gerunds
    (r'.*ed$', 'VBD'),                 # simple past
    (r'.*es$', 'VBZ'),                 # 3rd singular present
    (r'.*ould$', 'MD'),                # modals
    (r'.*\'s$', 'NN$'),                # possessive nouns
    (r'.*s$', 'NNS'),                  # plural nouns
    (r'^-?[0-9]+(\.[0-9]+)?$', 'CD'),  # cardinal numbers
    (r'.*', 'NN'),                      # nouns (default) 
    (r'.*ment$', 'NN'),                # i.e. wonderment 
    (r'.*ful$', 'JJ')                  # i.e. wonderful 
]
regexp_tagger = RegexpTagger(patterns)
display(regexp_tagger.tag(test_sent), regexp_tagger.evaluate(test_data))
# Out:
# [('The', 'NN'),
#  ('Fulton', 'NN'),
#  ('County', 'NN'),
#  ('Grand', 'NN'),
#  ('Jury', 'NN'),
#  ('said', 'NN'),
#  ('Friday', 'NN'),
#  ('an', 'NN'),
#  ('investigation', 'NN'),
#  ('of', 'NN'),
#  ("Atlanta's", 'NN$'),
#  ('recent', 'NN'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', 'NN'),
#  ('no', 'NN'),
#  ('evidence', 'NN'),
#  ("''", 'NN'),
#  ('that', 'NN'),
#  ('any', 'NN'),
#  ('irregularities', 'VBZ'),
#  ('took', 'NN'),
#  ('place', 'NN'),
#  ('.', 'NN')]
# 0.20253164556962025

# %% [markdown]
# Судя по результату, регулярных выражений в patterns не достаточно, чтобы покрыть большой процент слов корпуса.

# %% [markdown]
# #### Комбинация тэггеров
#
# Примущество Backoff Tagging в том, что если текущий тэггер не знает, как тэггировать слово, он передает это следующему и так далее, пока не пройдет перебор по всем тэггерам. В данному случае тэггирование производит последовательность UnigramTagger, BigramTagger, TrigramTagger. Комбинация тэггеров дала немного лучший результат, чем UnigramTagger, BigramTagger по отдельности.

# %%
from nltk.tag import TrigramTagger 

def backoff_tagger(train_sents, tagger_classes, backoff=None):
    for cls in tagger_classes:
        backoff = cls(train_sents, backoff=backoff)
    return backoff


backoff = DefaultTagger('NN') 
tag = backoff_tagger(train_data,  
                     [UnigramTagger, BigramTagger, TrigramTagger],  
                     backoff = backoff) 
  
tag.evaluate(test_data)
# Out:
# 0.843317053722715

# %% [markdown]
# #### Создание тэггера имен
#
# Подходим к теме именнованых сущностей (NER). Мы можем самостоятельно написать необходимый тэггер. Допустим, мы хотим тэггировать имена людей в тексте. Для этого берем корпус имен (nltk.corpus.names), создаем класс тэггера, задаем логику: если слово входит в множество имен, присваиваем ему тэг имени "NNP", иначе тэг "None".

# %%
nltk.download('names')
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\essor\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\names.zip.
# True

# %%
from nltk.tag import SequentialBackoffTagger
from nltk.corpus import names

class NamesTagger(SequentialBackoffTagger):
    def __init__(self, *args, **kwargs):
        SequentialBackoffTagger.__init__(self, *args, **kwargs)
        self.name_set = set([n.lower() for n in names.words()])
            
    def choose_tag(self, tokens, index, history):
        word = tokens[index]
        if word.lower() in self.name_set:
             return 'NNP'
        else:
             return None
            
nt = NamesTagger()
print(nt.tag(['Katya'])) 
print(nt.tag(['Adam'])) 
print(nt.tag(['Window']))
# Out:
# [('Katya', 'NNP')]
# [('Adam', 'NNP')]
# [('Window', None)]

# %% [markdown]
# Разметка предложений
#
# На вход тэггеру также можно подавать предложения, self.tag() будет применяться к каждому слову предложения.

# %%
bigram_tagger.tag_sents([['make', 'America', 'great', 'again'], ['winter', 'is', 'coming']])
# Out:
# [[('make', 'VB'), ('America', 'NP-TL'), ('great', 'JJ'), ('again', 'RB')],
#  [('winter', 'NN'), ('is', 'BEZ'), ('coming', 'VBG')]]

# %% [markdown]
# ####  Разметка корпусов
#
# Некоторые из корпусов, включенных в NLTK, были уже размечены. Вот пример того, что вы можете увидеть, если откроете nltk.corpus.brown

# %%
nltk.corpus.brown.tagged_words()
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\essor\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\universal_tagset.zip.
# True

# %%
nltk.corpus.brown.tagged_words(tagset='universal')
# Out:
# [('The', 'DET'), ('Fulton', 'NOUN'), ...]

# %% [markdown]
# Частота частей речи в корпусе

# %%
brown_news_tagged = nltk.corpus.brown.tagged_words(categories='adventure', tagset='universal')
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
tag_fd.most_common()
# Out:
# [('NOUN', 13354),
#  ('VERB', 12274),
#  ('.', 10929),
#  ('DET', 8155),
#  ('ADP', 7069),
#  ('PRON', 5205),
#  ('ADV', 3879),
#  ('ADJ', 3364),
#  ('PRT', 2436),
#  ('CONJ', 2173),
#  ('NUM', 466),
#  ('X', 38)]

# %%
w_fd = nltk.FreqDist(word for (word, tag) in brown_news_tagged)
w_fd.most_common()
# Out:
# [('.', 4057),
#  (',', 3488),
#  ('the', 3370),
#  ('and', 1622),
#  ('a', 1354),
#  ('of', 1322),
#  ('to', 1309),
#  ('``', 998),
#  ("''", 995),
#  ('was', 914),
#  ('in', 847),
#  ('his', 776),
#  ('he', 761),
#  ('I', 652),
#  ('had', 591),
#  ('He', 522),
#  ('?', 518),
#  ('that', 494),
#  ('it', 492),
#  ('on', 460),
#  ('her', 444),
#  ('him', 415),
#  ('The', 410),
#  ('with', 401),
#  ('you', 362),
#  ('for', 331),
#  ('at', 317),
#  ('!', 314),
#  ('as', 310),
#  ('said', 287),
#  ('out', 266),
#  ('from', 260),
#  ('were', 251),
#  ('she', 240),
#  ('up', 226),
#  (';', 216),
#  ('--', 213),
#  ('me', 207),
#  ('they', 206),
#  ('this', 203),
#  ('but', 197),
#  ('would', 191),
#  ('be', 183),
#  ('into', 180),
#  ('not', 179),
#  ('my', 168),
#  ('all', 167),
#  ('back', 165),
#  ('man', 165),
#  ('one', 162),
#  ('an', 159),
#  ('their', 156),
#  ('them', 156),
#  ('down', 153),
#  ('could', 151),
#  ('by', 147),
#  ('It', 145),
#  ('She', 137),
#  ('like', 136),
#  ('have', 133),
#  ('there', 133),
#  ('been', 131),
#  ('time', 127),
#  ('when', 126),
#  ('no', 125),
#  ('But', 119),
#  ('about', 119),
#  ('over', 118),
#  ('or', 115),
#  ('so', 114),
#  ('what', 110),
#  ('which', 100),
#  ('then', 99),
#  ('They', 99),
#  ('only', 98),
#  ('is', 98),
#  ('do', 93),
#  ('get', 92),
#  ('who', 91),
#  ('if', 91),
#  ('now', 90),
#  ('eyes', 90),
#  ('we', 87),
#  ('off', 87),
#  ('You', 84),
#  ('did', 84),
#  ('And', 84),
#  ('more', 83),
#  ('before', 83),
#  ('men', 81),
#  ('two', 80),
#  ('got', 80),
#  ('came', 79),
#  ('see', 79),
#  ('right', 79),
#  ('through', 78),
#  ('A', 78),
#  ('made', 77),
#  ('himself', 75),
#  ('face', 74),
#  ('just', 74),
#  ('go', 73),
#  ('again', 73),
#  ('long', 72),
#  ('around', 71),
#  ('head', 71),
#  (':', 71),
#  ('away', 71),
#  ("didn't", 70),
#  ('His', 70),
#  ('little', 67),
#  ('saw', 67),
#  ('door', 67),
#  ('even', 66),
#  ('here', 65),
#  ('its', 65),
#  ('took', 65),
#  ('hand', 65),
#  ("don't", 65),
#  ('way', 65),
#  ('too', 64),
#  ('against', 63),
#  ('thought', 62),
#  ('still', 62),
#  ('looked', 62),
#  ('never', 62),
#  ('come', 61),
#  ('went', 60),
#  ('than', 60),
#  ('house', 60),
#  ('other', 60),
#  ('water', 59),
#  ('your', 59),
#  ('There', 59),
#  ('might', 58),
#  ('know', 58),
#  ('any', 56),
#  ('first', 55),
#  ('much', 54),
#  ('knew', 54),
#  ('girl', 53),
#  ('turned', 53),
#  ('where', 53),
#  ('after', 53),
#  ('side', 52),
#  ('some', 51),
#  ('going', 50),
#  ("I'm", 50),
#  ('something', 50),
#  ('will', 50),
#  ('big', 50),
#  ('feet', 49),
#  ('make', 49),
#  ('If', 48),
#  ('toward', 48),
#  ('No', 48),
#  ('hands', 48),
#  ('are', 48),
#  ('behind', 48),
#  ('When', 47),
#  ('left', 47),
#  ('us', 47),
#  ('told', 46),
#  ('can', 46),
#  ('across', 46),
#  ('In', 45),
#  ('while', 45),
#  ('think', 44),
#  ('want', 43),
#  ('own', 43),
#  ('boy', 42),
#  ('voice', 42),
#  ('without', 42),
#  ('last', 41),
#  ('very', 41),
#  ('under', 40),
#  ('dark', 40),
#  ('heard', 40),
#  ('seemed', 40),
#  ('day', 39),
#  ('few', 39),
#  ('front', 39),
#  ('What', 39),
#  ('our', 39),
#  ('place', 39),
#  ('began', 39),
#  ('That', 39),
#  ('nothing', 38),
#  ('started', 38),
#  ('Then', 38),
#  ('let', 38),
#  ('take', 38),
#  ('old', 38),
#  ('open', 38),
#  ('Now', 37),
#  ('good', 37),
#  ('hair', 37),
#  ('inside', 37),
#  ('found', 36),
#  ('reached', 36),
#  ('until', 36),
#  ('stood', 36),
#  ('almost', 36),
#  ('This', 36),
#  ('mind', 36),
#  ('look', 36),
#  ('car', 36),
#  ('enough', 35),
#  ('how', 35),
#  ('fire', 35),
#  ('three', 35),
#  ("I'll", 35),
#  ('small', 35),
#  ('hall', 35),
#  ('Matsuo', 35),
#  ('felt', 34),
#  ('say', 34),
#  ('horses', 34),
#  ('asked', 33),
#  ('room', 33),
#  ('seen', 33),
#  ('ran', 33),
#  ('Jess', 33),
#  ('years', 32),
#  ('moment', 32),
#  ('We', 32),
#  ('once', 32),
#  ('marine', 32),
#  ('hard', 31),
#  ('work', 31),
#  ('body', 31),
#  ('valley', 31),
#  ('gun', 31),
#  ('Curt', 31),
#  ('night', 30),
#  ('rifle', 30),
#  ('far', 30),
#  ('better', 30),
#  ('shot', 30),
#  ('woman', 29),
#  ('both', 29),
#  ('life', 29),
#  ('moved', 29),
#  ('ground', 29),
#  ('tell', 29),
#  ('Brannon', 29),
#  ('Morgan', 28),
#  ('well', 28),
#  ('thing', 28),
#  ('walked', 28),
#  ('anything', 28),
#  ('these', 28),
#  ('brought', 28),
#  ('town', 28),
#  ('Mike', 28),
#  ('As', 28),
#  ('Ramey', 28),
#  ('most', 27),
#  ('give', 27),
#  ('minutes', 27),
#  ('ever', 27),
#  ('must', 27),
#  ('held', 27),
#  ('morning', 27),
#  ('those', 27),
#  ('wagon', 27),
#  ('another', 27),
#  ('For', 27),
#  ('each', 26),
#  ('along', 26),
#  ('sure', 26),
#  ("couldn't", 26),
#  ('black', 26),
#  ('white', 26),
#  ('bottle', 26),
#  ('wife', 25),
#  ("wouldn't", 25),
#  ('because', 25),
#  ('dead', 25),
#  ('light', 25),
#  ('dropped', 25),
#  ('line', 25),
#  ("man's", 25),
#  ('At', 25),
#  ('turn', 25),
#  ('home', 25),
#  ('Barton', 25),
#  ('Greg', 25),
#  ('Tilghman', 25),
#  ('caught', 24),
#  ('people', 24),
#  ('young', 24),
#  ('Her', 24),
#  ("I've", 24),
#  ('Not', 24),
#  ('followed', 24),
#  ('All', 24),
#  ('though', 24),
#  ('end', 24),
#  ('Dan', 23),
#  ('sat', 23),
#  ('hear', 23),
#  ('put', 23),
#  ('mouth', 23),
#  ('gave', 23),
#  ('arm', 23),
#  ('Lord', 23),
#  ('Tom', 23),
#  ('gone', 23),
#  ('air', 23),
#  ('floor', 23),
#  ('Jack', 23),
#  ('hit', 23),
#  ('above', 23),
#  ('sound', 23),
#  ('street', 23),
#  ('new', 22),
#  ('days', 22),
#  ('Mr.', 22),
#  ('many', 22),
#  ('wall', 22),
#  ('words', 22),
#  ('Just', 22),
#  ('called', 22),
#  ('So', 22),
#  ('near', 22),
#  ('next', 22),
#  ('(', 22),
#  (')', 22),
#  ('lips', 21),
#  ('sun', 21),
#  ('several', 21),
#  ('running', 21),
#  ('How', 21),
#  ('My', 21),
#  ('part', 21),
#  ('yet', 21),
#  ('horse', 21),
#  ('passed', 21),
#  ('trees', 21),
#  ('later', 21),
#  ('close', 21),
#  ('One', 21),
#  ('else', 21),
#  ('Well', 21),
#  ('always', 21),
#  ('Penny', 21),
#  ('Miss', 21),
#  ('thinking', 20),
#  ('every', 20),
#  ('watched', 20),
#  ('half', 20),
#  ('death', 20),
#  ("That's", 20),
#  ("It's", 20),
#  ("you're", 20),
#  ('wanted', 20),
#  ('neck', 20),
#  ('shoulder', 20),
#  ('chance', 20),
#  ('upon', 20),
#  ('second', 20),
#  ("ain't", 20),
#  ('Maybe', 20),
#  ('road', 20),
#  ('Russ', 20),
#  ('Keith', 20),
#  ('stay', 19),
#  ('being', 19),
#  ('kind', 19),
#  ('looking', 19),
#  ('mean', 19),
#  ('feel', 19),
#  ('Clayton', 19),
#  ('forward', 19),
#  ('high', 19),
#  ('others', 19),
#  ('With', 19),
#  ('also', 19),
#  ('rear', 19),
#  ('between', 19),
#  ('corner', 19),
#  ('past', 19),
#  ('such', 19),
#  ('pulled', 19),
#  ('women', 19),
#  ('truck', 19),
#  ('opened', 19),
#  ('Pat', 19),
#  ('leave', 18),
#  ('really', 18),
#  ('doing', 18),
#  ("You're", 18),
#  ('Mrs.', 18),
#  ('find', 18),
#  ('steps', 18),
#  ('riding', 18),
#  ('same', 18),
#  ("I'd", 18),
#  ('war', 18),
#  ('probably', 18),
#  ('great', 18),
#  ('quite', 18),
#  ('things', 18),
#  ('name', 18),
#  ('Even', 18),
#  ('Blue', 18),
#  ('girls', 18),
#  ('Langford', 18),
#  ('trouble', 17),
#  ('stopped', 17),
#  ('walk', 17),
#  ("There's", 17),
#  ('arms', 17),
#  ("wasn't", 17),
#  ('Billy', 17),
#  ('Why', 17),
#  ('help', 17),
#  ("can't", 17),
#  ('set', 17),
#  ('Oh', 17),
#  ('stared', 17),
#  ('strong', 17),
#  ('bed', 17),
#  ('shook', 17),
#  ('ago', 17),
#  ('swung', 17),
#  ('soon', 17),
#  ('kept', 17),
#  ('legs', 17),
#  ('Wilson', 17),
#  ('straight', 17),
#  ('Pamela', 17),
#  ('Joyce', 17),
#  ('window', 17),
#  ('Cobb', 17),
#  ('dive', 17),
#  ('Lalaurie', 17),
#  ('country', 16),
#  ('happened', 16),
#  ('move', 16),
#  ('lifted', 16),
#  ('money', 16),
#  ('job', 16),
#  ('suddenly', 16),
#  ('course', 16),
#  ('getting', 16),
#  ('tried', 16),
#  ('land', 16),
#  ('river', 16),
#  ('hundred', 16),
#  ('ride', 16),
#  ('showed', 16),
#  ('within', 16),
#  ('blood', 16),
#  ('green', 16),
#  ('four', 16),
#  ('already', 16),
#  ('sight', 16),
#  ('office', 16),
#  ('jungle', 16),
#  ('tree', 16),
#  ('Nicolas', 16),
#  ('carried', 15),
#  ('top', 15),
#  ('least', 15),
#  ('lay', 15),
#  ('drink', 15),
#  ('red', 15),
#  ('nodded', 15),
#  ('six', 15),
#  ('use', 15),
#  ('either', 15),
#  ("We'll", 15),
#  ('keep', 15),
#  ("it's", 15),
#  ('together', 15),
#  ('since', 15),
#  ('killed', 15),
#  ('father', 15),
#  ('yards', 15),
#  ("He's", 15),
#  ("won't", 15),
#  ('beneath', 15),
#  ('talk', 15),
#  ('trying', 15),
#  ('became', 15),
#  ('world', 15),
#  ('done', 15),
#  ('waiting', 15),
#  ('matter', 15),
#  ('has', 15),
#  ('should', 15),
#  ('show', 15),
#  ('sort', 15),
#  ('enemy', 15),
#  ("'", 15),
#  ('Dandy', 15),
#  ('Ernie', 15),
#  ('fast', 14),
#  ('slowly', 14),
#  ('care', 14),
#  ('shoulders', 14),
#  ('filled', 14),
#  ('miles', 14),
#  ("hadn't", 14),
#  ('need', 14),
#  ('ready', 14),
#  ('hung', 14),
#  ('known', 14),
#  ('meant', 14),
#  ('Yes', 14),
#  ('saddle', 14),
#  ('cold', 14),
#  ('figure', 14),
#  ('maybe', 14),
#  ('alone', 14),
#  ('feeling', 14),
#  ('slightly', 14),
#  ('pistol', 14),
#  ('hat', 14),
#  ('try', 14),
#  ('deep', 14),
#  ('pool', 14),
#  ('large', 14),
#  ('wore', 14),
#  ('climbed', 14),
#  ('drew', 14),
#  ('After', 14),
#  ('mother', 14),
#  ("Don't", 14),
#  ("Jess's", 14),
#  ('Mary', 14),
#  ('Benson', 14),
#  ('Waddell', 14),
#  ('less', 13),
#  ('grass', 13),
#  ('hours', 13),
#  ('rest', 13),
#  ('fell', 13),
#  ('making', 13),
#  ('porch', 13),
#  ('kill', 13),
#  ('beside', 13),
#  ('five', 13),
#  ('wide', 13),
#  ("he's", 13),
#  ('quickly', 13),
#  ('understand', 13),
#  ('why', 13),
#  ('Gavin', 13),
#  ('broke', 13),
#  ('son', 13),
#  ('chest', 13),
#  ('barn', 13),
#  ('To', 13),
#  ('circle', 13),
#  ('yelled', 13),
#  ('seem', 13),
#  ('appeared', 13),
#  ('dust', 13),
#  ('tall', 13),
#  ('longer', 13),
#  ('aware', 13),
#  ("Let's", 13),
#  ('pocket', 13),
#  ('husband', 13),
#  ('Rod', 13),
#  ('Johnson', 13),
#  ("he'd", 12),
#  ('sleep', 12),
#  ('best', 12),
#  ('spring', 12),
#  ('picked', 12),
#  ('moving', 12),
#  ('waited', 12),
#  ('possible', 12),
#  ('thin', 12),
#  ('used', 12),
#  ('coming', 12),
#  ('shirt', 12),
#  ('remember', 12),
#  ('Come', 12),
#  ('darkness', 12),
#  ('led', 12),
#  ('child', 12),
#  ('rode', 12),
#  ('cattle', 12),
#  ("that's", 12),
#  ('distance', 12),
#  ('bullet', 12),
#  ('taking', 12),
#  ('standing', 12),
#  ("'em", 12),
#  ('Indian', 12),
#  ('onto', 12),
#  ('hour', 12),
#  ('smiled', 12),
#  ('pull', 12),
#  ('sent', 12),
#  ('stop', 12),
#  ('counter', 12),
#  ('times', 12),
#  ('brown', 12),
#  ('nose', 12),
#  ('headed', 12),
#  ('play', 12),
#  ('Charles', 12),
#  ('store', 12),
#  ('fingers', 12),
#  ('Uncle', 12),
#  ('Brassnose', 12),
#  ('school', 12),
#  ('Delphine', 12),
#  ('Feathertop', 12),
#  ('Cappy', 12),
#  ('hurt', 11),
#  ('spent', 11),
#  ('case', 11),
#  ('ahead', 11),
#  ('clothes', 11),
#  ('table', 11),
#  ('murmured', 11),
#  ('returned', 11),
#  ('Jones', 11),
#  ('ranch', 11),
#  ('year', 11),
#  ('finally', 11),
#  ('guess', 11),
#  ('throat', 11),
#  ('whispered', 11),
#  ('closed', 11),
#  ('stepped', 11),
#  ('easy', 11),
#  ('finished', 11),
#  ('someone', 11),
#  ('stand', 11),
#  ('gray', 11),
#  ('hills', 11),
#  ('loose', 11),
#  ('cheek', 11),
#  ('clear', 11),
#  ('clouds', 11),
#  ('beat', 11),
#  ('Dean', 11),
#  ('remained', 11),
#  ('herself', 11),
#  ('having', 11),
#  ('touched', 11),
#  ('return', 11),
#  ('Hell', 11),
#  ('Once', 11),
#  ('knife', 11),
#  ('except', 11),
#  ('run', 11),
#  ('watching', 11),
#  ('bit', 11),
#  ('breath', 11),
#  ('coat', 11),
#  ('attention', 11),
#  ('ten', 11),
#  ('wondered', 11),
#  ('Dill', 11),
#  ('heart', 11),
#  ('teeth', 11),
#  ('McBride', 11),
#  ('sitting', 11),
#  ('boys', 11),
#  ('plane', 11),
#  ('driver', 11),
#  ('Jane', 11),
#  ('beauty', 11),
#  ('German', 11),
#  ('Throat', 11),
#  ('slave', 11),
#  ('often', 10),
#  ('point', 10),
#  ('burned', 10),
#  ('foot', 10),
#  ('edge', 10),
#  ('bath', 10),
#  ('Your', 10),
#  ('laughed', 10),
#  ('lot', 10),
#  ('lost', 10),
#  ('catch', 10),
#  ('fight', 10),
#  ('believed', 10),
#  ('slipped', 10),
#  ('God', 10),
#  ('spread', 10),
#  ('faces', 10),
#  ('dirt', 10),
#  ('lived', 10),
#  ('outside', 10),
#  ('stockade', 10),
#  ('myself', 10),
#  ('cut', 10),
#  ('talking', 10),
#  ('guerrillas', 10),
#  ('guard', 10),
#  ('Bill', 10),
#  ('luck', 10),
#  ('met', 10),
#  ('buildings', 10),
#  ('guns', 10),
#  ('peered', 10),
#  ('shouted', 10),
#  ('Montero', 10),
#  ('anyone', 10),
#  ('company', 10),
#  ('although', 10),
#  ('ball', 10),
#  ('surprise', 10),
#  ('From', 10),
#  ('Louis', 10),
#  ('grabbed', 10),
#  ('friend', 10),
#  ('noticed', 10),
#  ('expected', 10),
#  ('clerk', 10),
#  ("What's", 10),
#  ('snake', 10),
#  ('forest', 10),
#  ('pushed', 10),
#  ("o'", 10),
#  ('kid', 10),
#  ('Lewis', 10),
#  ('killing', 10),
#  ('stall', 10),
#  ('Sally', 10),
#  ('train', 10),
#  ('watch', 10),
#  ('Carmer', 10),
#  ('Todman', 10),
#  ('New', 10),
#  ('Meredith', 10),
#  ('youth', 10),
#  ('dry', 9),
#  ('hot', 9),
#  ('warm', 9),
#  ('late', 9),
#  ('afternoon', 9),
#  ('immediately', 9),
#  ('closer', 9),
#  ('dirty', 9),
#  ('couple', 9),
#  ('Get', 9),
#  ('skin', 9),
#  ('dress', 9),
#  ('chair', 9),
#  ('blonde', 9),
#  ('bad', 9),
#  ("He'd", 9),
#  ('terrible', 9),
#  ("isn't", 9),
#  ('pain', 9),
#  ("there's", 9),
#  ('flesh', 9),
#  ("doesn't", 9),
#  ('taken', 9),
#  ('wind', 9),
#  ('low', 9),
#  ('worked', 9),
#  ('love', 9),
#  ('smile', 9),
#  ('neither', 9),
#  ('reach', 9),
#  ('fact', 9),
#  ('using', 9),
#  ('Susan', 9),
#  ('dozen', 9),
#  ('yourself', 9),
#  ('spoke', 9),
#  ('hardly', 9),
#  ('area', 9),
#  ('rolled', 9),
#  ('beyond', 9),
#  ('center', 9),
#  ('children', 9),
#  ('position', 9),
#  ('covered', 9),
#  ('wait', 9),
#  ('seat', 9),
#  ('whole', 9),
#  ('step', 9),
#  ('am', 9),
#  ("you've", 9),
#  ('everything', 9),
#  ('perhaps', 9),
#  ('heavy', 9),
#  ('pale', 9),
#  ('person', 9),
#  ('On', 9),
#  ('instead', 9),
#  ('By', 9),
#  ('pass', 9),
#  ('rather', 9),
#  ('short', 9),
#  ('turning', 9),
#  ('Hague', 9),
#  ('simple', 9),
#  ('mountain', 9),
#  ('evening', 9),
#  ('continued', 9),
#  ('thick', 9),
#  ('grinned', 9),
#  ('stomach', 9),
#  ('murder', 9),
#  ('rain', 9),
#  ('Brenner', 9),
#  ('draw', 9),
#  ('Gran', 9),
#  ('bar', 9),
#  ('speed', 9),
#  ('Roebuck', 9),
#  ('Eromonga', 9),
#  ('Schaffner', 9),
#  ('gang', 9),
#  ('gonna', 9),
#  ('Madame', 9),
#  ('married', 8),
#  ('simply', 8),
#  ('summer', 8),
#  ('drop', 8),
#  ('holster', 8),
#  ('south', 8),
#  ('meadow', 8),
#  ('north', 8),
#  ('angry', 8),
#  ('knees', 8),
#  ('fool', 8),
#  ("we're", 8),
#  ('giving', 8),
#  ('shape', 8),
#  ('stretched', 8),
#  ('helped', 8),
#  ("We're", 8),
#  ('early', 8),
#  ('kids', 8),
#  ('free', 8),
#  ('call', 8),
#  ('anger', 8),
#  ("Gavin's", 8),
#  ('English', 8),
#  ('hate', 8),
#  ('bring', 8),
#  ('blanket', 8),
#  ('Two', 8),
#  ('laid', 8),
#  ('nice', 8),
#  ('burning', 8),
#  ('below', 8),
#  ('remembered', 8),
#  ('Roy', 8),
#  ('nor', 8),
#  ('trail', 8),
#  ('whether', 8),
#  ('offered', 8),
#  ('none', 8),
#  ('walls', 8),
#  ('telling', 8),
#  ('able', 8),
#  ('flight', 8),
#  ('east', 8),
#  ('bag', 8),
#  ('iron', 8),
#  ('drove', 8),
#  ('windows', 8),
#  ('leg', 8),
#  ('wrong', 8),
#  ('live', 8),
#  ('Old', 8),
#  ('replied', 8),
#  ('Eyes', 8),
#  ('lead', 8),
#  ('bare', 8),
#  ('fall', 8),
#  ('leaped', 8),
#  ('grew', 8),
#  ('fighting', 8),
#  ('aim', 8),
#  ('quirt', 8),
#  ('size', 8),
#  ('handsome', 8),
#  ('business', 8),
#  ('answer', 8),
#  ('listen', 8),
#  ('hoped', 8),
#  ('needed', 8),
#  ('stayed', 8),
#  ('single', 8),
#  ('hope', 8),
#  ('radio', 8),
#  ('pick', 8),
#  ('itself', 8),
#  ('lights', 8),
#  ('smoke', 8),
#  ('desk', 8),
#  ('read', 8),
#  ('growing', 8),
#  ('Rankin', 8),
#  ('escape', 8),
#  ('spot', 8),
#  ('wheel', 8),
#  ('dream', 8),
#  ('direction', 8),
#  ('entered', 8),
#  ('thoughts', 8),
#  ('word', 8),
#  ('named', 8),
#  ('ask', 8),
#  ('Hogan', 8),
#  ('Macklin', 8),
#  ('skirt', 8),
#  ('wheels', 8),
#  ("Curt's", 8),
#  ('carefully', 8),
#  ('piece', 8),
#  ('oxen', 8),
#  ('Harmony', 8),
#  ('tight', 8),
#  ('Stevens', 8),
#  ("Greg's", 8),
#  ('jumped', 8),
#  ('full', 8),
#  ('American', 8),
#  ('slowed', 8),
#  ('drivers', 8),
#  ('Ah', 8),
#  ('trunk', 8),
#  ('Robinson', 8),
#  ('Rob', 8),
#  ('Artie', 8),
#  ('marines', 8),
#  ('schoolhouse', 8),
#  ('teacher', 8),
#  ('Winchester', 7),
#  ('leaned', 7),
#  ('studied', 7),
#  ('crawled', 7),
#  ('twenty', 7),
#  ('shoot', 7),
#  ('jerked', 7),
#  ('kitchen', 7),
#  ('completely', 7),
#  ('Besides', 7),
#  ('sweet', 7),
#  ('blue', 7),
#  ('faint', 7),
#  ('Thank', 7),
#  ('wagons', 7),
#  ('placed', 7),
#  ("haven't", 7),
#  ('mighty', 7),
#  ('empty', 7),
#  ("you'd", 7),
#  ('meal', 7),
#  ('sorry', 7),
#  ("you'll", 7),
#  ("they'd", 7),
#  ('rose', 7),
#  ('wiped', 7),
#  ('round', 7),
#  ('heat', 7),
#  ('post', 7),
#  ('fresh', 7),
#  ('silence', 7),
#  ('bend', 7),
#  ('blow', 7),
#  ('sky', 7),
#  ('cracked', 7),
#  ('dance', 7),
#  ('wild', 7),
#  ('raised', 7),
#  ('shut', 7),
#  ('sunlight', 7),
#  ('earth', 7),
#  ('gold', 7),
#  ('flat', 7),
#  ('pointed', 7),
#  ('crossed', 7),
#  ('belt', 7),
#  ('main', 7),
#  ('living', 7),
#  ('handed', 7),
#  ('hell', 7),
#  ('careful', 7),
#  ('straightened', 7),
#  ('motion', 7),
#  ('west', 7),
#  ('frame', 7),
#  ('seized', 7),
#  ('powder', 7),
#  ('form', 7),
#  ('minute', 7),
#  ('realized', 7),
#  ('truth', 7),
#  ('aside', 7),
#  ('cover', 7),
#  ...]

# %%
top_w = pd.DataFrame(w_fd.most_common())

# %%
top_w[0].head(300)
# Out:
# 0             .
# 1             ,
# 2           the
# 3           and
# 4             a
#          ...
# 295    followed
# 296         All
# 297      though
# 298         end
# 299         Dan
# Name: 0, Length: 300, dtype: object

# %%
top_w[0].to_csv("tops1.csv",index=False)

# %%
list(set(top_w[0].head(300)))
# Out:
# ['you',
#  'then',
#  'each',
#  'one',
#  'while',
#  'have',
#  'fire',
#  'think',
#  'for',
#  'time',
#  'because',
#  'few',
#  'Barton',
#  'never',
#  'is',
#  'three',
#  'Then',
#  'he',
#  'boy',
#  'so',
#  'had',
#  'me',
#  'want',
#  'Curt',
#  'turn',
#  'these',
#  'as',
#  'there',
#  'not',
#  'even',
#  ',',
#  'last',
#  'very',
#  'they',
#  "wouldn't",
#  'told',
#  'get',
#  'still',
#  'water',
#  'inside',
#  'thing',
#  'better',
#  'take',
#  'You',
#  'asked',
#  '?',
#  'how',
#  'been',
#  'once',
#  'could',
#  'himself',
#  'make',
#  'open',
#  'good',
#  'It',
#  'behind',
#  'most',
#  'work',
#  'car',
#  'young',
#  'horses',
#  'again',
#  'would',
#  'No',
#  'and',
#  'The',
#  'now',
#  'heard',
#  'night',
#  'ever',
#  'the',
#  'back',
#  'what',
#  'Greg',
#  'hard',
#  'Dan',
#  'home',
#  'woman',
#  'dark',
#  'little',
#  'way',
#  'around',
#  'through',
#  'we',
#  'started',
#  'before',
#  'And',
#  'something',
#  'into',
#  'began',
#  'Jess',
#  'well',
#  'Tilghman',
#  'first',
#  'than',
#  'Brannon',
#  'from',
#  'years',
#  'other',
#  'There',
#  'were',
#  'in',
#  'another',
#  'far',
#  ':',
#  'out',
#  'though',
#  "didn't",
#  'nothing',
#  'any',
#  'place',
#  'sure',
#  'be',
#  'just',
#  'saw',
#  'hands',
#  'no',
#  'or',
#  "''",
#  'took',
#  'house',
#  'some',
#  'across',
#  '.',
#  'can',
#  'both',
#  ';',
#  'rifle',
#  'walked',
#  'it',
#  'come',
#  'came',
#  'only',
#  'ran',
#  'tell',
#  'They',
#  '!',
#  'day',
#  'brought',
#  'by',
#  'town',
#  'up',
#  'too',
#  'see',
#  'black',
#  'stood',
#  'face',
#  'said',
#  "couldn't",
#  'off',
#  'He',
#  'door',
#  'them',
#  'That',
#  'will',
#  'without',
#  'left',
#  'body',
#  'small',
#  'anything',
#  'toward',
#  'looked',
#  'A',
#  'might',
#  'Matsuo',
#  'shot',
#  'light',
#  'at',
#  'Ramey',
#  'At',
#  "I've",
#  'got',
#  'where',
#  'room',
#  'hand',
#  'away',
#  'mind',
#  'moved',
#  'if',
#  'In',
#  'This',
#  'say',
#  'line',
#  'followed',
#  'His',
#  'As',
#  '--',
#  'almost',
#  'an',
#  'his',
#  'of',
#  'men',
#  'our',
#  'valley',
#  'She',
#  'more',
#  'Morgan',
#  'did',
#  'on',
#  'your',
#  'end',
#  'with',
#  'When',
#  'let',
#  'until',
#  'give',
#  'that',
#  'are',
#  'For',
#  'all',
#  'own',
#  'Not',
#  'found',
#  'go',
#  'front',
#  'dropped',
#  'which',
#  'against',
#  'big',
#  'Now',
#  "don't",
#  'look',
#  'after',
#  'people',
#  'old',
#  'morning',
#  'dead',
#  'man',
#  'much',
#  'turned',
#  'their',
#  '``',
#  'reached',
#  'But',
#  'long',
#  'life',
#  'she',
#  'a',
#  'right',
#  'two',
#  'If',
#  'under',
#  'seen',
#  'along',
#  'knew',
#  'about',
#  'ground',
#  'seemed',
#  "I'll",
#  'side',
#  'must',
#  'us',
#  'white',
#  'this',
#  'Her',
#  'I',
#  'like',
#  'eyes',
#  'went',
#  'hall',
#  'All',
#  'felt',
#  'What',
#  'bottle',
#  'my',
#  'when',
#  'Mike',
#  'minutes',
#  'who',
#  'but',
#  'feet',
#  'was',
#  'marine',
#  "man's",
#  'its',
#  'voice',
#  'wagon',
#  "I'm",
#  'head',
#  'to',
#  'him',
#  'wife',
#  'held',
#  'made',
#  'those',
#  'do',
#  'down',
#  'girl',
#  'here',
#  'know',
#  'going',
#  'moment',
#  'over',
#  'gun',
#  'thought',
#  'hair',
#  'We',
#  'caught',
#  'enough',
#  'her']

# %%
# !pip install pyconll
# Out:
# Collecting pyconll
#   Downloading pyconll-2.3.3-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests>=2.21 in c:\programs\anaconda3\lib\site-packages (from pyconll) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programs\anaconda3\lib\site-packages (from requests>=2.21->pyconll) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programs\anaconda3\lib\site-packages (from requests>=2.21->pyconll) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\programs\anaconda3\lib\site-packages (from requests>=2.21->pyconll) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programs\anaconda3\lib\site-packages (from requests>=2.21->pyconll) (2020.6.20)
# Installing collected packages: pyconll
# Successfully installed pyconll-2.3.3

# %%
import pyconll

# %%
# !wget -O ./datasets/ru_syntagrus-ud-train.conllu https://raw.githubusercontent.com/UniversalDependencies/UD_Russian-SynTagRus/master/ru_syntagrus-ud-train.conllu
# !wget -O ./datasets/ru_syntagrus-ud-dev.conllu https://raw.githubusercontent.com/UniversalDependencies/UD_Russian-SynTagRus/master/ru_syntagrus-ud-dev.conllu
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
full_train = pyconll.load_from_file('datasets/ru_syntagrus-ud-train.conllu')
full_test = pyconll.load_from_file('datasets/ru_syntagrus-ud-dev.conllu')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-69e81765e3eb> in <module>
# ----> 1 full_train = pyconll.load_from_file('datasets/ru_syntagrus-ud-train.conllu')
#       2 full_test = pyconll.load_from_file('datasets/ru_syntagrus-ud-dev.conllu')
#
# C:\Programs\anaconda3\lib\site-packages\pyconll\load.py in load_from_file(filename)
#      45         ParseError: If there is an error parsing the input into a Conll object.
#      46     """
# ---> 47     with open(filename, encoding='utf-8') as f:
#      48         c = Conll(f)
#      49
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/ru_syntagrus-ud-train.conllu'

# %%
for sent in full_train[:2]:
    for token in sent:
        print(token.form, token.upos)
    print()
# Out:
# Анкета NOUN
# . PUNCT
#
# Начальник NOUN
# областного ADJ
# управления NOUN
# связи NOUN
# Семен PROPN
# Еремеевич PROPN
# был AUX
# человек NOUN
# простой ADJ
# , PUNCT
# приходил VERB
# на ADP
# работу NOUN
# всегда ADV
# вовремя ADV
# , PUNCT
# здоровался VERB
# с ADP
# секретаршей NOUN
# за ADP
# руку NOUN
# и CCONJ
# иногда ADV
# даже PART
# писал VERB
# в ADP
# стенгазету NOUN
# заметки NOUN
# под ADP
# псевдонимом NOUN
# " PUNCT
# Муха NOUN
# " PUNCT
# . PUNCT

# %%
fdata_train = []
for sent in full_train[:]:
    fdata_train.append([(token.form, token.upos) for token in sent])
    
fdata_test = []
for sent in full_test[:]:
    fdata_test.append([(token.form, token.upos) for token in sent])
    
fdata_sent_test = []
for sent in full_test[:]:
    fdata_sent_test.append([token.form for token in sent])

# %%
MAX_SENT_LEN = max(len(sent) for sent in full_train)
MAX_ORIG_TOKEN_LEN = max(len(token.form) for sent in full_train for token in sent)
print('Наибольшая длина предложения', MAX_SENT_LEN)
print('Наибольшая длина токена', MAX_ORIG_TOKEN_LEN)
# Out:
# Наибольшая длина предложения 205
# Наибольшая длина токена 47

# %%
all_train_texts = [' '.join(token.form for token in sent) for sent in full_train]
all_test_texts = [' '.join(token.form for token in sent) for sent in full_test]

all_train_labels = [' '.join(token.form for token in sent) for sent in full_train]
all_test_labels = [' '.join(token.form for token in sent) for sent in full_test]
print('\n'.join(all_train_texts[:10]))
# Out:
# Анкета .
# Начальник областного управления связи Семен Еремеевич был человек простой , приходил на работу всегда вовремя , здоровался с секретаршей за руку и иногда даже писал в стенгазету заметки под псевдонимом " Муха " .
# В приемной его с утра ожидали посетители , - кое-кто с важными делами , а кое-кто и с такими , которые легко можно было решить в нижестоящих инстанциях , не затрудняя Семена Еремеевича .
# Однако стиль работы Семена Еремеевича заключался в том , чтобы принимать всех желающих и лично вникать в дело .
# Приемная была обставлена просто , но по-деловому .
# У двери стоял стол секретарши , на столе - пишущая машинка с широкой кареткой .
# В углу висел репродуктор и играло радио для развлечения ожидающих и еще для того , чтобы заглушать голос начальника , доносившийся из кабинета , так как , бесспорно , среди посетителей могли находиться и случайные люди .
# Кабинет отличался скромностью , присущей Семену Еремеевичу .
# В глубине стоял широкий письменный стол с бронзовыми чернильницами и перед ним два кожаных кресла .
# Справа был стол для заседаний - длинный , накрытый зеленым сукном и с обеих сторон аккуратно заставленный стульями .

# %%
bigram_tagger = BigramTagger(fdata_train, backoff=unigram_tagger)

# %%
display(bigram_tagger.tag(fdata_sent_test[100]), bigram_tagger.evaluate(fdata_test))
# Out:
# [('Это', 'PRON'),
#  ('сочинение', None),
#  ('известно', None),
#  ('во', 'ADP'),
#  ('многих', 'NUM'),
#  ('вариантах', None),
#  ('(', 'PUNCT'),
#  ('самые', 'ADJ'),
#  ('ранние', 'ADJ'),
#  ('из', 'ADP'),
#  ('них', 'PRON'),
#  ('почти', 'ADV'),
#  ('на', 'ADP'),
#  ('сто', 'NUM'),
#  ('лет', 'NOUN'),
#  ('старше', 'ADJ'),
#  (')', 'PUNCT'),
#  ('и', 'CCONJ'),
#  ('восходит', None),
#  ('к', 'ADP'),
#  ('ещё', None),
#  ('более', 'ADV'),
#  ('древним', None),
#  ('рукописям', None),
#  ('XVI', None),
#  ('в', 'ADP'),
#  ('.', 'PUNCT')]
# 0.6952279850369022

# %%
train_tok = []
train_label = []
for sent in fdata_train[:]:
    for tok in sent:
        train_tok.append(tok[0])
        train_label.append('NO_TAG' if tok[1] is None else tok[1])
        
test_tok = []
test_label = []
for sent in fdata_test[:]:
    for tok in sent:
        test_tok.append(tok[0])
        test_label.append('NO_TAG' if tok[1] is None else tok[1])

# %%
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
train_enc_labels = le.fit_transform(train_label)

# %%
test_enc_labels = le.transform(test_label)

# %%
le.classes_
# Out:
# array(['ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'INTJ', 'NOUN',
#        'NO_TAG', 'NUM', 'PART', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'SYM',
#        'VERB', 'X'], dtype='<U6')

# %%
hvectorizer = HashingVectorizer(ngram_range=(1, 3), analyzer='char', n_features=50)

# %%
X_train = hvectorizer.fit_transform(train_tok)

# %%
X_test = hvectorizer.transform(test_tok)

# %%
X_train.shape
# Out:
# (871526, 50)

# %%
lr = LogisticRegression(random_state=0, max_iter=10)
lr.fit(X_train, train_enc_labels)
# Out:
# /home/rzaharov@mvs.local/.local/share/virtualenvs/nlp-course-A3nIyBIP/lib/python3.8/site-packages/sklearn/linear_model/logistic.py:430: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   warnings.warn("Default solver will be changed to 'lbfgs' in 0.22. "
# /home/rzaharov@mvs.local/.local/share/virtualenvs/nlp-course-A3nIyBIP/lib/python3.8/site-packages/sklearn/linear_model/logistic.py:467: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   warnings.warn("Default multi_class will be changed to 'auto' in"
# /home/rzaharov@mvs.local/.local/share/virtualenvs/nlp-course-A3nIyBIP/lib/python3.8/site-packages/sklearn/linear_model/logistic.py:1542: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 16.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# /home/rzaharov@mvs.local/.local/share/virtualenvs/nlp-course-A3nIyBIP/lib/python3.8/site-packages/sklearn/svm/base.py:928: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10,
#                    multi_class='warn', n_jobs=-1, penalty='l2', random_state=0,
#                    solver='warn', tol=0.0001, verbose=0, warm_start=False)

# %%
pred = lr.predict(X_test)

# %%
accuracy_score(test_enc_labels, pred)
# Out:
# 0.6331092238735551

# %% [markdown]
# ### 3.4.  Извлечение именованных сущностей (NER) и отношений

# %% [markdown]
# Одна из самых популярных задач NLP – извлечении именованных сущностей (Named-entity recognition, NER). Задача NER – выделить спаны сущностей в тексте (спан – непрерывный фрагмент текста). Допустим, есть новостной текст, и мы хотим выделить в нем сущности (некоторый заранее зафиксированный набор — например, персоны, локации, организации, даты и так далее). Задача NER – понять, что участок текста “1 января 1997 года” является датой, “Кофи Аннан” – персоной, а “ООН” – организацией.
#
# ##### Зачем?
# 1.  Cтруктуризация неструктурированных данных. Пусть у вас есть какой-то текст (или набор текстов), и данные из него нужно ввести в базу данных (таблицу).
# 2. Шаг в сторону “понимания” текста. Это может как иметь самостоятельную ценность, так и помочь лучше решать другие задачи NLP. Без решения задачи NER тяжело представить себе решение многих задач NLP, допустим, разрешение местоименной анафоры или построение вопросно-ответных систем.
#
# Пример 1: Местоименная анафора позволяет нам понять, к какому элементу текста относится местоимение. Например, пусть мы хотим проанализировать текст “Прискакал Чарминг на белом коне. Принцесса выбежала ему навстречу и поцеловала его”. Если мы выделили на слове “Чарминг” сущность Персона, то машина сможет намного легче понять, что принцесса, скорее всего, поцеловала не коня, а принца Чарминга.
#
# Пример 2: Теперь приведем пример, как выделение именованных сущностей может помочь при построении вопросно-ответных систем. Если задать в вашем любимом поисковике вопрос «Кто играл роль Дарта Вейдера в фильме “Империя наносит ответный удар”», то с большой вероятностью вы получите верный ответ. Это делается как раз с помощью выделения именованных сущностей: выделяем сущности (фильм, роль и т. п.), понимаем, что нас спрашивают, и дальше ищем ответ в базе данных.
#
# Для решения NER-задач существуют множество инструментов. Рассмотрим несколько из них.

# %% [markdown]
# #### NLTK

# %% [markdown]
# <img src='image/nltk.PNG'>

# %% [markdown]
# Для разметки NER с помощью NLTK сначала производим токенизацию слов, затем POS тэггинг.
# В качестве документа возьмем статью 'https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news, распарсим ее с помощью BeautifulSoup.

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\essor\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
import requests
from bs4 import BeautifulSoup
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

document = url_to_string('https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news')

nltk.pos_tag(nltk.word_tokenize(document))
# Out:
# [('F.B.I', 'NNP'),
#  ('.', '.'),
#  ('Agent', 'NNP'),
#  ('Peter', 'NNP'),
#  ('Strzok', 'NNP'),
#  (',', ','),
#  ('Who', 'NNP'),
#  ('Criticized', 'NNP'),
#  ('Trump', 'NNP'),
#  ('in', 'IN'),
#  ('Texts', 'NNP'),
#  (',', ','),
#  ('Is', 'NNP'),
#  ('Fired', 'NNP'),
#  ('-', ':'),
#  ('The', 'DT'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('Times', 'NNP'),
#  ('SectionsSEARCHSkip', 'NNP'),
#  ('to', 'TO'),
#  ('contentSkip', 'VB'),
#  ('to', 'TO'),
#  ('site', 'NN'),
#  ('indexPoliticsToday', 'JJ'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('PaperPolitics|F.B.I', 'NNP'),
#  ('.', '.'),
#  ('Agent', 'NNP'),
#  ('Peter', 'NNP'),
#  ('Strzok', 'NNP'),
#  (',', ','),
#  ('Who', 'NNP'),
#  ('Criticized', 'NNP'),
#  ('Trump', 'NNP'),
#  ('in', 'IN'),
#  ('Texts', 'NNP'),
#  (',', ','),
#  ('Is', 'VBZ'),
#  ('Firedhttps', 'NNP'),
#  (':', ':'),
#  ('//nyti.ms/2OtNre3AdvertisementContinue', 'NN'),
#  ('reading', 'VBG'),
#  ('the', 'DT'),
#  ('main', 'JJ'),
#  ('storySupported', 'JJ'),
#  ('byContinue', 'NN'),
#  ('reading', 'VBG'),
#  ('the', 'DT'),
#  ('main', 'JJ'),
#  ('storyF.B.I', 'NN'),
#  ('.', '.'),
#  ('Agent', 'NNP'),
#  ('Peter', 'NNP'),
#  ('Strzok', 'NNP'),
#  (',', ','),
#  ('Who', 'NNP'),
#  ('Criticized', 'NNP'),
#  ('Trump', 'NNP'),
#  ('in', 'IN'),
#  ('Texts', 'NNP'),
#  (',', ','),
#  ('Is', 'NNP'),
#  ('FiredPeter', 'NNP'),
#  ('Strzok', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('top', 'JJ'),
#  ('F.B.I', 'NNP'),
#  ('.', '.'),
#  ('counterintelligence', 'NN'),
#  ('agent', 'NN'),
#  ('who', 'WP'),
#  ('was', 'VBD'),
#  ('taken', 'VBN'),
#  ('off', 'RP'),
#  ('the', 'DT'),
#  ('special', 'JJ'),
#  ('counsel', 'NN'),
#  ('investigation', 'NN'),
#  ('after', 'IN'),
#  ('his', 'PRP$'),
#  ('disparaging', 'NN'),
#  ('texts', 'NN'),
#  ('about', 'IN'),
#  ('President', 'NNP'),
#  ('Trump', 'NNP'),
#  ('were', 'VBD'),
#  ('uncovered', 'VBN'),
#  (',', ','),
#  ('was', 'VBD'),
#  ('fired.Credit', 'NN'),
#  ('...', ':'),
#  ('T.J.', 'NNP'),
#  ('Kirkpatrick', 'NNP'),
#  ('for', 'IN'),
#  ('The', 'DT'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('TimesBy', 'NNP'),
#  ('Adam', 'NNP'),
#  ('Goldman', 'NNP'),
#  ('and', 'CC'),
#  ('Michael', 'NNP'),
#  ('S.', 'NNP'),
#  ('SchmidtAug', 'NNP'),
#  ('.', '.'),
#  ('13', 'CD'),
#  (',', ','),
#  ('2018WASHINGTON', 'CD'),
#  ('—', 'NN'),
#  ('Peter', 'NNP'),
#  ('Strzok', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('F.B.I', 'NNP'),
#  ('.', '.'),
#  ('senior', 'JJ'),
#  ('counterintelligence', 'NN'),
#  ('agent', 'NN'),
#  ('who', 'WP'),
#  ('disparaged', 'VBD'),
#  ('President', 'NNP'),
#  ('Trump', 'NNP'),
#  ('in', 'IN'),
#  ('inflammatory', 'JJ'),
#  ('text', 'NN'),
#  ('messages', 'NNS'),
#  ('and', 'CC'),
#  ('helped', 'VBD'),
#  ('oversee', 'VB'),
#  ('the', 'DT'),
#  ('Hillary', 'NNP'),
#  ('Clinton', 'NNP'),
#  ('email', 'NN'),
#  ('and', 'CC'),
#  ('Russia', 'NNP'),
#  ('investigations', 'NNS'),
#  (',', ','),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('fired', 'VBN'),
#  ('for', 'IN'),
#  ('violating', 'VBG'),
#  ('bureau', 'NN'),
#  ('policies', 'NNS'),
#  (',', ','),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('lawyer', 'NN'),
#  ('said', 'VBD'),
#  ('Monday.Mr', 'NNP'),
#  ('.', '.'),
#  ('Trump', 'NNP'),
#  ('and', 'CC'),
#  ('his', 'PRP$'),
#  ('allies', 'NNS'),
#  ('seized', 'VBN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('texts', 'NN'),
#  ('—', 'NNP'),
#  ('exchanged', 'VBD'),
#  ('during', 'IN'),
#  ('the', 'DT'),
#  ('2016', 'CD'),
#  ('campaign', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('former', 'JJ'),
#  ('F.B.I', 'NNP'),
#  ('.', '.'),
#  ('lawyer', 'NN'),
#  (',', ','),
#  ('Lisa', 'NNP'),
#  ('Page', 'NNP'),
#  ('—', 'NNP'),
#  ('in', 'IN'),
#  ('assailing', 'VBG'),
#  ('the', 'DT'),
#  ('Russia', 'NNP'),
#  ('investigation', 'NN'),
#  ('as', 'IN'),
#  ('an', 'DT'),
#  ('illegitimate', 'NN'),
#  ('“', 'NN'),
#  ('witch', 'NN'),
#  ('hunt.', 'NN'),
#  ('”', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('rose', 'VBD'),
#  ('over', 'IN'),
#  ('20', 'CD'),
#  ('years', 'NNS'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('F.B.I', 'NNP'),
#  ('.', '.'),
#  ('to', 'TO'),
#  ('become', 'VB'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('most', 'RBS'),
#  ('experienced', 'JJ'),
#  ('counterintelligence', 'NN'),
#  ('agents', 'NNS'),
#  (',', ','),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('key', 'JJ'),
#  ('figure', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('early', 'JJ'),
#  ('months', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('inquiry.Along', 'JJ'),
#  ('with', 'IN'),
#  ('writing', 'VBG'),
#  ('the', 'DT'),
#  ('texts', 'NN'),
#  (',', ','),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('was', 'VBD'),
#  ('accused', 'VBN'),
#  ('of', 'IN'),
#  ('sending', 'VBG'),
#  ('a', 'DT'),
#  ('highly', 'RB'),
#  ('sensitive', 'JJ'),
#  ('search', 'NN'),
#  ('warrant', 'NN'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('personal', 'JJ'),
#  ('email', 'NN'),
#  ('account.The', 'NN'),
#  ('F.B.I', 'NNP'),
#  ('.', '.'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('under', 'IN'),
#  ('immense', 'JJ'),
#  ('political', 'JJ'),
#  ('pressure', 'NN'),
#  ('by', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('to', 'TO'),
#  ('dismiss', 'VB'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('was', 'VBD'),
#  ('removed', 'VBN'),
#  ('last', 'JJ'),
#  ('summer', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('staff', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('special', 'JJ'),
#  ('counsel', 'NN'),
#  (',', ','),
#  ('Robert', 'NNP'),
#  ('S.', 'NNP'),
#  ('Mueller', 'NNP'),
#  ('III', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('president', 'NN'),
#  ('has', 'VBZ'),
#  ('repeatedly', 'RB'),
#  ('denounced', 'VBN'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('in', 'IN'),
#  ('posts', 'NNS'),
#  ('on', 'IN'),
#  ('Twitter', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('on', 'IN'),
#  ('Monday', 'NNP'),
#  ('expressed', 'VBD'),
#  ('satisfaction', 'NN'),
#  ('that', 'IN'),
#  ('he', 'PRP'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('sacked.Mr', 'VBN'),
#  ('.', '.'),
#  ('Trump', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('victory', 'NN'),
#  ('traces', 'NNS'),
#  ('back', 'RB'),
#  ('to', 'TO'),
#  ('June', 'NNP'),
#  (',', ','),
#  ('when', 'WRB'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('conduct', 'NN'),
#  ('was', 'VBD'),
#  ('laid', 'VBN'),
#  ('out', 'RP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('wide-ranging', 'JJ'),
#  ('inspector', 'NN'),
#  ('general', 'JJ'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('report', 'NN'),
#  ('on', 'IN'),
#  ('how', 'WRB'),
#  ('the', 'DT'),
#  ('F.B.I', 'NNP'),
#  ('.', '.'),
#  ('handled', 'VBD'),
#  ('the', 'DT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ('Hillary', 'NNP'),
#  ('Clinton', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('emails', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('run-up', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('2016', 'CD'),
#  ('election', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('report', 'NN'),
#  ('was', 'VBD'),
#  ('critical', 'JJ'),
#  ('of', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('conduct', 'NN'),
#  ('in', 'IN'),
#  ('sending', 'VBG'),
#  ('the', 'DT'),
#  ('texts', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('bureau', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('Office', 'NNP'),
#  ('of', 'IN'),
#  ('Professional', 'NNP'),
#  ('Responsibility', 'NNP'),
#  ('said', 'VBD'),
#  ('that', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('suspended', 'VBN'),
#  ('for', 'IN'),
#  ('60', 'CD'),
#  ('days', 'NNS'),
#  ('and', 'CC'),
#  ('demoted', 'VBN'),
#  ('.', '.'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('had', 'VBD'),
#  ('testified', 'VBN'),
#  ('before', 'IN'),
#  ('the', 'DT'),
#  ('House', 'NNP'),
#  ('in', 'IN'),
#  ('July', 'NNP'),
#  ('about', 'IN'),
#  ('how', 'WRB'),
#  ('he', 'PRP'),
#  ('had', 'VBD'),
#  ('not', 'RB'),
#  ('allowed', 'VBN'),
#  ('his', 'PRP$'),
#  ('political', 'JJ'),
#  ('views', 'NNS'),
#  ('to', 'TO'),
#  ('interfere', 'VB'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('investigations', 'NNS'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('overseeing.But', 'JJ'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('lawyer', 'NN'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('deputy', 'NN'),
#  ('director', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('F.B.I.', 'NNP'),
#  (',', ','),
#  ('David', 'NNP'),
#  ('Bowdich', 'NNP'),
#  (',', ','),
#  ('had', 'VBD'),
#  ('overruled', 'VBN'),
#  ('the', 'DT'),
#  ('Office', 'NNP'),
#  ('of', 'IN'),
#  ('Professional', 'NNP'),
#  ('Responsibility', 'NNP'),
#  ('and', 'CC'),
#  ('fired', 'VBD'),
#  ('Mr.', 'NNP'),
#  ('Strzok.A', 'NNP'),
#  ('spokeswoman', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('F.B.I', 'NNP'),
#  ('.', '.'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('respond', 'VB'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('message', 'NN'),
#  ('seeking', 'VBG'),
#  ('comment', 'NN'),
#  ('about', 'RB'),
#  ('why', 'WRB'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('was', 'VBD'),
#  ('dismissed', 'VBN'),
#  ('rather', 'RB'),
#  ('than', 'IN'),
#  ('demoted', 'VBN'),
#  ('.', '.'),
#  ('Firing', 'VBG'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  (',', ','),
#  ('however', 'RB'),
#  (',', ','),
#  ('removes', 'VBZ'),
#  ('a', 'DT'),
#  ('favorite', 'JJ'),
#  ('target', 'NN'),
#  ('of', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('ranks', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('F.B.I', 'NNP'),
#  ('.', '.'),
#  ('and', 'CC'),
#  ('gives', 'VBZ'),
#  ('Mr.', 'NNP'),
#  ('Bowdich', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('F.B.I', 'NNP'),
#  ('.', '.'),
#  ('director', 'NN'),
#  (',', ','),
#  ('Christopher', 'NNP'),
#  ('A.', 'NN'),
#  ('Wray', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('chance', 'NN'),
#  ('to', 'TO'),
#  ('move', 'VB'),
#  ('beyond', 'IN'),
#  ('the', 'DT'),
#  ('president', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('ire.Aitan', 'NN'),
#  ('Goelman', 'NNP'),
#  (',', ','),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('lawyer', 'NN'),
#  (',', ','),
#  ('denounced', 'VBD'),
#  ('his', 'PRP$'),
#  ('client', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('dismissal', 'NN'),
#  ('.', '.'),
#  ('“', 'VB'),
#  ('The', 'DT'),
#  ('decision', 'NN'),
#  ('to', 'TO'),
#  ('fire', 'VB'),
#  ('Special', 'JJ'),
#  ('Agent', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('only', 'RB'),
#  ('a', 'DT'),
#  ('departure', 'NN'),
#  ('from', 'IN'),
#  ('typical', 'JJ'),
#  ('bureau', 'NN'),
#  ('practice', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('also', 'RB'),
#  ('contradicts', 'VBZ'),
#  ('Director', 'NNP'),
#  ('Wray', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('testimony', 'NN'),
#  ('to', 'TO'),
#  ('Congress', 'NNP'),
#  ('and', 'CC'),
#  ('his', 'PRP$'),
#  ('assurances', 'NNS'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('F.B.I', 'NNP'),
#  ('.', '.'),
#  ('intended', 'VBN'),
#  ('to', 'TO'),
#  ('follow', 'VB'),
#  ('its', 'PRP$'),
#  ('regular', 'JJ'),
#  ('process', 'NN'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('and', 'CC'),
#  ('all', 'DT'),
#  ('personnel', 'NNS'),
#  ('matters', 'NNS'),
#  (',', ','),
#  ('”', 'VBP'),
#  ('Mr.', 'NNP'),
#  ('Goelman', 'NNP'),
#  ('said.', 'VBZ'),
#  ('“', 'VB'),
#  ('This', 'DT'),
#  ('decision', 'NN'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('deeply', 'RB'),
#  ('troubling', 'VBG'),
#  ('to', 'TO'),
#  ('all', 'DT'),
#  ('Americans', 'NNPS'),
#  (',', ','),
#  ('”', 'FW'),
#  ('Mr.', 'NNP'),
#  ('Goelman', 'NNP'),
#  ('added', 'VBD'),
#  ('.', '.'),
#  ('“', 'VB'),
#  ('A', 'NNP'),
#  ('lengthy', 'JJ'),
#  ('investigation', 'NN'),
#  ('and', 'CC'),
#  ('multiple', 'JJ'),
#  ('rounds', 'NNS'),
#  ('of', 'IN'),
#  ('congressional', 'JJ'),
#  ('testimony', 'NN'),
#  ('failed', 'VBD'),
#  ('to', 'TO'),
#  ('produce', 'VB'),
#  ('a', 'DT'),
#  ('shred', 'NN'),
#  ('of', 'IN'),
#  ('evidence', 'NN'),
#  ('that', 'IN'),
#  ('Special', 'JJ'),
#  ('Agent', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('personal', 'JJ'),
#  ('views', 'NNS'),
#  ('ever', 'RB'),
#  ('affected', 'VBD'),
#  ('his', 'PRP$'),
#  ('work.', 'NN'),
#  ('”', 'NNP'),
#  ('Mr', 'NNP'),
#  ('.', '.'),
#  ('Strzok', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('text', 'JJ'),
#  ('exchanges', 'NNS'),
#  ('with', 'IN'),
#  ('Ms', 'NNP'),
#  ('.', '.'),
#  ('Page', 'NN'),
#  ('demonstrated', 'VBD'),
#  ('animosity', 'NN'),
#  ('toward', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('one', 'CD'),
#  (',', ','),
#  ('Ms', 'NNP'),
#  ('.', '.'),
#  ('Page', 'NN'),
#  ('asks', 'VBZ'),
#  (':', ':'),
#  ('Trump', 'NN'),
#  ('is', 'VBZ'),
#  ('“', 'JJ'),
#  ('not', 'RB'),
#  ('ever', 'RB'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('become', 'VB'),
#  ('president', 'NN'),
#  (',', ','),
#  ('right', 'RB'),
#  ('?', '.'),
#  ('Right', 'RB'),
#  ('?', '.'),
#  ('!', '.'),
#  ('”', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('responds', 'VBZ'),
#  (':', ':'),
#  ('“', 'NN'),
#  ('No', 'NNP'),
#  ('.', '.'),
#  ('No', 'CC'),
#  ('he', 'PRP'),
#  ('won', 'VBD'),
#  ('’', 'NNP'),
#  ('t', 'NN'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('’', 'VBP'),
#  ('ll', 'JJ'),
#  ('stop', 'NN'),
#  ('it.', 'NN'),
#  ('”', 'VBD'),
#  ('The', 'DT'),
#  ('inspector', 'NN'),
#  ('general', 'JJ'),
#  (',', ','),
#  ('who', 'WP'),
#  ('uncovered', 'VBD'),
#  ('the', 'DT'),
#  ('messages', 'NNS'),
#  (',', ','),
#  ('found', 'VBD'),
#  ('no', 'DT'),
#  ('evidence', 'NN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('pair', 'NN'),
#  ('imposed', 'VBD'),
#  ('their', 'PRP$'),
#  ('political', 'JJ'),
#  ('views', 'NNS'),
#  ('on', 'IN'),
#  ('their', 'PRP$'),
#  ('investigative', 'JJ'),
#  ('decisions', 'NNS'),
#  ('but', 'CC'),
#  ('cited', 'VBD'),
#  ('that', 'DT'),
#  ('exchange', 'NN'),
#  ('as', 'IN'),
#  ('“', 'NN'),
#  ('not', 'RB'),
#  ('only', 'RB'),
#  ('indicative', 'JJ'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('biased', 'JJ'),
#  ('state', 'NN'),
#  ('of', 'IN'),
#  ('mind', 'NN'),
#  ('but', 'CC'),
#  (',', ','),
#  ('even', 'RB'),
#  ('more', 'RBR'),
#  ('seriously', 'RB'),
#  (',', ','),
#  ('implies', 'VBZ'),
#  ('a', 'DT'),
#  ('willingness', 'NN'),
#  ('to', 'TO'),
#  ('take', 'VB'),
#  ('official', 'JJ'),
#  ('action', 'NN'),
#  ('to', 'TO'),
#  ('impact', 'VB'),
#  ('the', 'DT'),
#  ('presidential', 'JJ'),
#  ('candidate', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('electoral', 'JJ'),
#  ('prospects.', 'NN'),
#  ('”', 'VBD'),
#  ('The', 'DT'),
#  ('report', 'NN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('inspector', 'NN'),
#  ('general', 'NN'),
#  (',', ','),
#  ('Michael', 'NNP'),
#  ('E.', 'NNP'),
#  ('Horowitz', 'NNP'),
#  (',', ','),
#  ('that', 'WDT'),
#  ('preceded', 'VBD'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('firing', 'VBG'),
#  ('not', 'RB'),
#  ('only', 'RB'),
#  ('criticized', 'VBD'),
#  ('his', 'PRP$'),
#  ('conduct', 'NN'),
#  ('in', 'IN'),
#  ('sending', 'VBG'),
#  ('the', 'DT'),
#  ('texts', 'NN'),
#  ('but', 'CC'),
#  ('also', 'RB'),
#  ('his', 'PRP$'),
#  ('use', 'NN'),
#  ('of', 'IN'),
#  ('personal', 'JJ'),
#  ('email', 'NN'),
#  ('accounts', 'NNS'),
#  ('to', 'TO'),
#  ('handle', 'VB'),
#  ('sensitive', 'JJ'),
#  ('information', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('addition', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('inspector', 'NN'),
#  ('general', 'JJ'),
#  ('criticized', 'VBD'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'POS'),
#  ('decision', 'NN'),
#  ('not', 'RB'),
#  ('to', 'TO'),
#  ('move', 'VB'),
#  ('swiftly', 'RB'),
#  ('to', 'TO'),
#  ('examine', 'VB'),
#  ('new', 'JJ'),
#  ('emails', 'NNS'),
#  ('related', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('Clinton', 'NNP'),
#  ('investigation', 'NN'),
#  ('just', 'RB'),
#  ('weeks', 'NNS'),
#  ('before', 'IN'),
#  ('the', 'DT'),
#  ('2016', 'CD'),
#  ('election.Mr', 'NN'),
#  ('.', '.'),
#  ('Horowitz', 'NNP'),
#  ('said', 'VBD'),
#  ('in', 'IN'),
#  ('his', 'PRP$'),
#  ('report', 'NN'),
#  ('that', 'IN'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('“', 'JJ'),
#  ('deeply', 'RB'),
#  ('troubled', 'JJ'),
#  ('”', 'NN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('text', 'NN'),
#  ('messages', 'NNS'),
#  ('.', '.'),
#  ('Hundreds', 'NNS'),
#  ('exchanged', 'VBD'),
#  ('over', 'IN'),
#  ('months', 'NNS'),
#  ('were', 'VBD'),
#  ('found', 'VBN'),
#  ('in', 'IN'),
#  ('which', 'WDT'),
#  ('the', 'DT'),
#  ('pair', 'NN'),
#  ('disparaged', 'VBD'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('and', 'CC'),
#  (',', ','),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('lesser', 'JJR'),
#  ('extent', 'NN'),
#  (',', ','),
#  ('Mrs.', 'NNP'),
#  ('Clinton', 'NNP'),
#  (',', ','),
#  ('exchanged', 'VBD'),
#  ('work', 'NN'),
#  ('gossip', 'NN'),
#  ('and', 'CC'),
#  ('bantered.On', 'NN'),
#  ('Twitter', 'NNP'),
#  (',', ','),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('said', 'VBD'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('“', 'JJ'),
#  ('deeply', 'RB'),
#  ('saddened', 'VBN'),
#  ('by', 'IN'),
#  ('this', 'DT'),
#  ('decision', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('adding', 'VBG'),
#  (',', ','),
#  ('“', 'NN'),
#  ('It', 'PRP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('an', 'DT'),
#  ('honor', 'NN'),
#  ('to', 'TO'),
#  ('serve', 'VB'),
#  ('my', 'PRP$'),
#  ('country', 'NN'),
#  ('and', 'CC'),
#  ('work', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('fine', 'JJ'),
#  ('men', 'NNS'),
#  ('and', 'CC'),
#  ('women', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('FBI.', 'NNP'),
#  ('”', 'NNP'),
#  ('Mr', 'NNP'),
#  ('.', '.'),
#  ('Strzok', 'NNP'),
#  ('became', 'VBD'),
#  ('emblematic', 'JJ'),
#  ('of', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('unfounded', 'VBD'),
#  ('assertions', 'NNS'),
#  ('that', 'IN'),
#  ('a', 'DT'),
#  ('so-called', 'JJ'),
#  ('deep', 'JJ'),
#  ('state', 'NN'),
#  ('of', 'IN'),
#  ('bureaucrats', 'NNS'),
#  ('opposed', 'VBN'),
#  ('to', 'TO'),
#  ('him', 'PRP'),
#  ('was', 'VBD'),
#  ('undermining', 'VBG'),
#  ('his', 'PRP$'),
#  ('presidency', 'NN'),
#  ('.', '.'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('contended', 'VBD'),
#  ('that', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('targeted', 'VBD'),
#  ('the', 'DT'),
#  ('president', 'NN'),
#  ('and', 'CC'),
#  ('accused', 'VBD'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('of', 'IN'),
#  ('being', 'VBG'),
#  ('“', 'NNP'),
#  ('treasonous', 'JJ'),
#  ('”', 'NN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('“', 'JJ'),
#  ('disgrace.', 'NN'),
#  ('”', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('told', 'VBD'),
#  ('lawmakers', 'NNS'),
#  ('that', 'IN'),
#  ('he', 'PRP'),
#  ('never', 'RB'),
#  ('leaked', 'VBD'),
#  ('information', 'NN'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('Russia', 'NNP'),
#  ('inquiry', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('could', 'MD'),
#  ('have', 'VB'),
#  ('upended', 'VBN'),
#  ('the', 'DT'),
#  ('election', 'NN'),
#  ('and', 'CC'),
#  ('hurt', 'VB'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('chances', 'NNS'),
#  ('of', 'IN'),
#  ('becoming', 'VBG'),
#  ('president.After', 'NN'),
#  ('Mr.', 'NNP'),
#  ('Horowitz', 'NNP'),
#  ('uncovered', 'VBD'),
#  ('the', 'DT'),
#  ('texts', 'NN'),
#  (',', ','),
#  ('Mr.', 'NNP'),
#  ('Mueller', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('had', 'VBD'),
#  ('by', 'IN'),
#  ('then', 'RB'),
#  ('taken', 'VBN'),
#  ('over', 'RP'),
#  ('the', 'DT'),
#  ('investigation', 'NN'),
#  (',', ','),
#  ('removed', 'VBD'),
#  ('Mr.', 'NNP'),
#  ('Strzok', 'NNP'),
#  ('from', 'IN'),
#  ...]

# %% [markdown]
# С помощью функции nltk.ne_chunk () мы можем распознавать именованные сущности с помощью классификатора, который добавляет метки категорий, такие как PERSON, ORGANIZATION и GPE.

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\essor\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\essor\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
{(' '.join(c[0] for c in chunk), chunk.label() ) for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(document))) if hasattr(chunk, 'label') }
# Out:
# {('Agent Peter Strzok', 'PERSON'),
#  ('Andrew G. McCabe', 'PERSON'),
#  ('Anthony D. Weiner', 'PERSON'),
#  ('Army', 'ORGANIZATION'),
#  ('China', 'GPE'),
#  ('Christopher', 'PERSON'),
#  ('Clinton', 'PERSON'),
#  ('CompanyNYTCoContact', 'ORGANIZATION'),
#  ('Congress', 'ORGANIZATION'),
#  ('David Bowdich', 'PERSON'),
#  ('Director Wray', 'PERSON'),
#  ('F.B.I.', 'ORGANIZATION'),
#  ('Georgetown University', 'ORGANIZATION'),
#  ('Goelman', 'PERSON'),
#  ('Hillary', 'ORGANIZATION'),
#  ('Hillary Clinton', 'PERSON'),
#  ('Horowitz', 'PERSON'),
#  ('House', 'ORGANIZATION'),
#  ('Hundreds', 'PERSON'),
#  ('IndexSite Information', 'ORGANIZATION'),
#  ('Is', 'PERSON'),
#  ('Is Fired', 'PERSON'),
#  ('James B. Comey', 'PERSON'),
#  ('Lisa Page', 'PERSON'),
#  ('March', 'GPE'),
#  ('Michael E. Horowitz', 'PERSON'),
#  ('Michael S. SchmidtAug', 'PERSON'),
#  ('Midyear Exam', 'PERSON'),
#  ('Mr.', 'PERSON'),
#  ('Mr. Bowdich', 'PERSON'),
#  ('Mr. Goelman', 'PERSON'),
#  ('Mr. Horowitz', 'PERSON'),
#  ('Mr. McCabe', 'PERSON'),
#  ('Mr. Mueller', 'PERSON'),
#  ('Mr. Strzok', 'PERSON'),
#  ('Mr. Trump', 'PERSON'),
#  ('Mr. Weiner', 'PERSON'),
#  ('New York', 'GPE'),
#  ('Page', 'PERSON'),
#  ('Peter Strzok', 'PERSON'),
#  ('Robert S. Mueller III', 'PERSON'),
#  ('Russia', 'GPE'),
#  ('Russia', 'GSP'),
#  ('Russian', 'GPE'),
#  ('SaleSite', 'ORGANIZATION'),
#  ('ServiceTerms', 'ORGANIZATION'),
#  ('Special Agent Strzok', 'ORGANIZATION'),
#  ('Strzok', 'PERSON'),
#  ('Texts', 'GPE'),
#  ('Times', 'PERSON'),
#  ('TimesBy Adam Goldman', 'ORGANIZATION'),
#  ('Trump', 'PERSON'),
#  ('Twitter', 'PERSON'),
#  ('USA', 'ORGANIZATION'),
#  ('United', 'ORGANIZATION'),
#  ('Weiner', 'ORGANIZATION'),
#  ('Who Criticized Trump', 'PERSON'),
#  ('Wray', 'PERSON'),
#  ('byContinue', 'ORGANIZATION'),
#  ('storySite', 'ORGANIZATION'),
#  ('usAdvertiseT Brand', 'ORGANIZATION')}

# %% [markdown]
# #### Spacy
#
# Spacy значительно быстрее NLTK, так как она написана на Cython и работает с объектами.
# Для NER Spacy работает как простой классификатор (неглубокая нейронная сеть с одним скрытым слоем). Объект Doc хранит последовательности токенов и все их аннотации.

# %% [markdown]
# <img src='image/spacy.PNG'>

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_md
# Out:
# Requirement already satisfied: spacy in c:\programs\anaconda3\lib\site-packages (2.3.4)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\programs\anaconda3\lib\site-packages (from spacy) (7.4.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\programs\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\programs\anaconda3\lib\site-packages (from spacy) (1.19.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programs\anaconda3\lib\site-packages (from spacy) (4.50.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\programs\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: setuptools in c:\programs\anaconda3\lib\site-packages (from spacy) (50.3.1.post20201107)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\programs\anaconda3\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\programs\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programs\anaconda3\lib\site-packages (from spacy) (2.24.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0; python_version >= "3.6" in c:\programs\anaconda3\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\programs\anaconda3\lib\site-packages (from spacy) (0.8.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\programs\anaconda3\lib\site-packages (from spacy) (2.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\programs\anaconda3\lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Collecting en_core_web_sm==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in c:\programs\anaconda3\lib\site-packages (from en_core_web_sm==2.3.1) (2.3.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.24.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0; python_version >= "3.6" in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.7.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.19.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.5)
# Requirement already satisfied: setuptools in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (50.3.1.post20201107)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.50.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py): started
#   Building wheel for en-core-web-sm (setup.py): finished with status 'done'
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.1-py3-none-any.whl size=12047113 sha256=08a17c026f9ef4366ee4b02c0b82eb73a22c53fb488118c2363fe4d4904b4d67
#   Stored in directory: C:\Users\essor\AppData\Local\Temp\pip-ephem-wheel-cache-6z9xblfu\wheels\ee\4d\f7\563214122be1540b5f9197b52cb3ddb9c4a8070808b22d5a84
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.0
#     Uninstalling en-core-web-sm-2.2.0:
#       Successfully uninstalled en-core-web-sm-2.2.0
# Successfully installed en-core-web-sm-2.3.1
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# Collecting en_core_web_md==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.3.1/en_core_web_md-2.3.1.tar.gz (50.8 MB)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in c:\programs\anaconda3\lib\site-packages (from en_core_web_md==2.3.1) (2.3.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.0.5)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (7.4.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0; python_version >= "3.6" in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (0.7.4)
# Requirement already satisfied: setuptools in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (50.3.1.post20201107)
# Requirement already satisfied: numpy>=1.15.0 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.19.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (0.8.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (3.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (4.50.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.24.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\programs\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programs\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (3.0.4)
# Building wheels for collected packages: en-core-web-md
#   Building wheel for en-core-web-md (setup.py): started
#   Building wheel for en-core-web-md (setup.py): finished with status 'done'
#   Created wheel for en-core-web-md: filename=en_core_web_md-2.3.1-py3-none-any.whl size=50916645 sha256=e884cfd0de80cb34db7a44a97def712b9df303753a632398671337161daee5b6
#   Stored in directory: C:\Users\essor\AppData\Local\Temp\pip-ephem-wheel-cache-9cr_joym\wheels\b8\ae\ae\c63bae74a3b3e18b2fa35e179387e6cdeb03a1c479ed45c351
# Successfully built en-core-web-md
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-2.3.1
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%
#!pip install -U spacy
#!python -m spacy info
import spacy
from spacy import displacy
import en_core_web_md

nlp = en_core_web_md.load()
ny_bb = url_to_string('https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news')
article = nlp(ny_bb)
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in Texts, Is Fired - The New York Times
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SectionsSEARCHSkip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  to contentSkip to site indexPoliticsToday’s PaperPolitics|F.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in Texts, Is Firedhttps://nyti.ms/2OtNre3AdvertisementContinue reading the main storySupported
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     byContinue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  reading the main storyF.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in Texts, Is FiredPeter Strzok, a top
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  counterintelligence agent who was taken off the special counsel investigation after his disparaging texts about President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  were uncovered, was fired.Credit...
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T.J. Kirkpatrick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York TimesBy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adam Goldman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael S. SchmidtAug
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018WASHINGTON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  —
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  senior counterintelligence agent who disparaged President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in inflammatory text messages and helped oversee the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hillary Clinton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  email and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">

# %%
ny_bb1 = url_to_string('https://www.nytimes.com/2020/12/09/technology/personaltech/amazon-halo-review.html')
article = nlp(ny_bb1)
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon Halo Review
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : The Fitness Gadget We Don’t Deserve or Need -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                                                                                              SectionsSEARCHSkip to contentSkip to site indexPersonal
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TechToday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ’s
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PaperPersonal Tech|Amazon Halo Review:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  The Fitness Gadget We Don’t Deserve or
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Needhttps://nyti.ms/36Zh6HXThe Coronavirus OutbreakliveLatest UpdatesMaps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CasesBritain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s Vaccine RolloutVaccine TrackerFAQ: Vaccines and MoreAdvertisementContinue reading the main storySupported
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     byContinue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  reading the main storytech
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fixAmazon Halo Review
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# : The Fitness Gadget We Don’t Deserve or NeedThe retail giant claims that its health product is extremely precise at scanning body fat. I found otherwise.Credit...
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Glenn HarveyBy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brian X. ChenDec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020Many
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of us are in the same boat
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     these days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . With the coronavirus killing more people by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , we are increasingly stress-eating and drinking more alcohol. At the same time, with gyms shut down, we are sitting around more and glued to screens.So you may be wondering what I’m wondering: How is the pandemic affecting my body? Because we can’t easily leave the house to see doctors for nonemergencies, we are largely left to figure this out on our own.Enter the Halo, a new fitness-tracking bracelet from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  with a novel twist: It claims that by using a smartphone app to scan images of your body, it can tell you how much body fat you have much more precisely than past technologies. The bracelet also has a microphone to listen to your tone of voice and tell you how your mood sounds to other people. (The masochist inside me said, “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sign me up!”)The
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Halo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s foray into so-called wearable computers that keep an eye on our health, following in the footsteps of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</s

# %% [markdown]
# #### Deeppavlov
#
# DeepPavlov-это библиотека ИИ с открытым исходным кодом, построенная на TensorFlow и Keras. DeepPavlov предназначена для разработки чат-ботов и сложных разговорных систем, исследований в области nlp и, в частности, диалоговых систем.
#
# DeepPavlov использует несколько более новый вариант глубокой нейронной архитектуры Flair, известный как гибридная модель Bi-LSTM-CRF.
#
# <img src='image/deeppavlov.PNG'>
#
# Используем предтренированную модель "ner_ontonotes_bert_mult", которая работает с разными языками, в том числе и русским. Подадим на распознование предложение на русском языке.

# %%
# !python -m venv env 
# #.\env\Scripts\activate.bat
# !pip install deeppavlov
# !python -m deeppavlov install squad_bert

#!python -m deeppavlov install ner_ontonotes
import deeppavlov
from deeppavlov import configs, build_model
deeppavlov_ner = build_model(configs.ner.ner_rus, download=True)
rus_document = "Нью-Йорк, США, 30 апреля 2020, 01:01 — REGNUM В администрации президента США Дональда Трампа планируют пройти все этапы создания вакцины от коронавируса в ускоренном темпе и выпустить 100 млн доз до конца 2020 года, передаёт агентство Bloomberg со ссылкой на осведомлённые источники"
deeppavlov_ner([rus_document])
# Out:
# 2020-10-14 18:50:40.340 INFO in 'deeppavlov.download'['download'] at line 132: Skipped http://files.deeppavlov.ai/deeppavlov_data/ner_rus_v3_cpu_compatible.tar.gz download because of matching hashes
# 2020-10-14 18:50:43.201 INFO in 'deeppavlov.download'['download'] at line 132: Skipped http://files.deeppavlov.ai/embeddings/lenta_lower_100.bin download because of matching hashes
# 2020-10-14 18:50:43.476 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /home/rzaharov@mvs.local/.deeppavlov/models/ner_rus/word.dict]
# 2020-10-14 18:50:43.532 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /home/rzaharov@mvs.local/.deeppavlov/models/ner_rus/tag.dict]
# 2020-10-14 18:50:43.535 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /home/rzaharov@mvs.local/.deeppavlov/models/ner_rus/char.dict]
# 2020-10-14 18:50:43.552 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/home/rzaharov@mvs.local/.deeppavlov/downloads/embeddings/lenta_lower_100.bin`]
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-e88113c37b4b> in <module>
#       7 import deeppavlov
#       8 from deeppavlov import configs, build_model
# ----> 9 deeppavlov_ner = build_model(configs.ner.ner_rus, download=True)
#      10 rus_document = "Нью-Йорк, США, 30 апреля 2020, 01:01 — REGNUM В администрации президента США Дональда Трампа планируют пройти все этапы создания вакцины от коронавируса в ускоренном темпе и выпустить 100 млн доз до конца 2020 года, передаёт агентство Bloomberg со ссылкой на осведомлённые источники"
#      11 deeppavlov_ner([rus_document])
#
# ~/.local/share/virtualenvs/nlp-course-A3nIyBIP/lib/python3.8/site-packages/deeppavlov/core/commands/infer.py in build_model(config, mode, load_trained, download, serialized)
#      60             component_serialized = None
#      61
# ---> 62         component = from_params(component_config, mode=mode, serialized=component_serialized)
#      63
#      64         if 'id' in component_config:
#
# ~/.local/share/virtualenvs/nlp-course-A3nIyBIP/lib/python3.8/site-packages/deeppavlov/core/common/params.py in from_params(params, mode, serialized, **kwargs)
#      93         log.exception(e)
#      94         raise e
# ---> 95     obj = get_model(cls_name)
#      96
#      97     if inspect.isclass(obj):
#
# ~/.local/share/virtualenvs/nlp-course-A3nIyBIP/lib/python3.8/site-packages/deeppavlov/core/common/registry.py in get_model(name)
#      70             raise ConfigError("Model {} is not registered.".format(name))
#      71         return cls_from_str(name)
# ---> 72     return cls_from_str(_REGISTRY[name])
#      73
#      74
#
# ~/.local/share/virtualenvs/nlp-course-A3nIyBIP/lib/python3.8/site-packages/deeppavlov/core/common/registry.py in cls_from_str(name)
#      38                           .format(name))
#      39
# ---> 40     return getattr(importlib.import_module(module_name), cls_name)
#      41
#      42
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.local/share/virtualenvs/nlp-course-A3nIyBIP/lib/python3.8/site-packages/deeppavlov/models/ner/network.py in <module>
#      20
#      21 from deeppavlov.core.common.registry import register
# ---> 22 from deeppavlov.core.layers.tf_layers import cudnn_bi_lstm, cudnn_bi_gru, bi_rnn, stacked_cnn, INITIALIZER
#      23 from deeppavlov.core.layers.tf_layers import embedding_layer, character_embedding_network, variational_dropout
#      24 from deeppavlov.core.models.tf_model import LRScheduledTFModel
#
# ~/.local/share/virtualenvs/nlp-course-A3nIyBIP/lib/python3.8/site-packages/deeppavlov/core/layers/tf_layers.py in <module>
#      23 log = getLogger(__name__)
#      24
# ---> 25 INITIALIZER = tf.orthogonal_initializer
#      26
#      27
#
# AttributeError: module 'tensorflow' has no attribute 'orthogonal_initializer'

# %% [markdown]
# ### 3.4. Извлечение отношений
#
# Можно извлекать не только именнованные сущности (NER), но и отношения между словами в предложении (Relation extraction).

# %% [markdown]
# #### Spacy
#
# В уже знакомой нам библеотеке Spacy используем встроенные displaCy визуализатор со style="dep" для отображения отношений.

# %%
import spacy
from spacy import displacy
#install spacy model
#!pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.2.0/en_core_web_md-2.2.0.tar.gz
import en_core_web_md
nlp = en_core_web_md.load()
doc = nlp("I think Barack Obama met founder of Facebook at occasion of a release of a new NLP algorithm.")

displacy.render(doc, style="dep") # (1)
displacy.render(doc, style="ent") # (2)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="52640dd662544908b5e281348de6799a-0" class="displacy" width="3200" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">think</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Barack</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Obama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">met</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">founder</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Facebook</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">occasion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">release</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">NLP</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">algorithm.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52640dd662544908b5e281348de6799a-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52640dd662544908b5e281348de6799a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52640dd662544908b5e281348de6799a-0-1" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52640dd662544908b5e281348de6799a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52640dd662544908b5e281348de6799a-0-2" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52640dd662544908b5e281348de6799a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52640dd662544908b5e281348de6799a-0-3" stroke-width="2px" d="M245,352.0 C245,89.5 745.0,89.5 745.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52640dd662544908b5e281348de6799a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,354.0 L753.0,342.0 737.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52640dd662544908b5e281348de6799a-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52640dd662544908b5e281348de6799a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910.0,354.0 L918.0,342.0 902.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52640dd662544908b5e281348de6799a-0-5" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I think
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  met founder of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at occasion of a release of a new
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  algorithm.</div></span>

# %% [markdown]
# #### NLTK
#
# Распарсим документ nltk.corpus.ieer.parsed_docs('NYT_19980315'), extract_rels позволяет нам выделять необходимые отношения, в данном случае мы ищем пары сущностей <'ORG', 'LOC'>. Также мы указали, что текст должен подходить под регулярное выражение IN.

# %%
import re
import nltk
IN = re.compile(r'.*\bin\b(?!\b.+ing)')
for doc in nltk.corpus.ieer.parsed_docs('NYT_19980315'):
     for rel in nltk.sem.extract_rels('ORG', 'LOC', doc,
                                      corpus='ieer', pattern = IN):
            print(nltk.sem.rtuple(rel))
# Out:
# [ORG: 'WHYY'] 'in' [LOC: 'Philadelphia']
# [ORG: 'McGlashan &AMP; Sarrail'] 'firm in' [LOC: 'San Mateo']
# [ORG: 'Freedom Forum'] 'in' [LOC: 'Arlington']
# [ORG: 'Brookings Institution'] ', the research group in' [LOC: 'Washington']
# [ORG: 'Idealab'] ', a self-described business incubator based in' [LOC: 'Los Angeles']
# [ORG: 'Open Text'] ', based in' [LOC: 'Waterloo']
# [ORG: 'WGBH'] 'in' [LOC: 'Boston']
# [ORG: 'Bastille Opera'] 'in' [LOC: 'Paris']
# [ORG: 'Omnicom'] 'in' [LOC: 'New York']
# [ORG: 'DDB Needham'] 'in' [LOC: 'New York']
# [ORG: 'Kaplan Thaler Group'] 'in' [LOC: 'New York']
# [ORG: 'BBDO South'] 'in' [LOC: 'Atlanta']
# [ORG: 'Georgia-Pacific'] 'in' [LOC: 'Atlanta']

# %% [markdown]
# #### Allennlp
#
# Попробовать извлекать отношения онлайн можно с помощью демо Allennlp  https://demo.allennlp.org/dependency-parsing/.
# Allen NLP предлагает две модели NER с различными архитектурами: Gated Recurrent Unit (GRU) Network, bi-LSTM-CRF model.

# %% [markdown]
# <img src='image/allennlp.PNG'>

# %%
from pymorphy2 import MorphAnalyzer

# %%
morpher = MorphAnalyzer()

# %%
morpher.parse("кошка")[0]
# Out:
# Parse(word='кошка', tag=OpencorporaTag('NOUN,anim,femn sing,nomn'), normal_form='кошка', score=0.833333, methods_stack=((<DictionaryAnalyzer>, 'кошка', 132, 0),))

# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,

    Doc
)

# %%
segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

text = 'Посол Израиля на Украине Йоэль Лион признался, что пришел в шок, узнав о решении властей Львовской области объявить 2019 год годом лидера запрещенной в России Организации украинских националистов (ОУН) Степана Бандеры. Свое заявление он разместил в Twitter. «Я не могу понять, как прославление тех, кто непосредственно принимал участие в ужасных антисемитских преступлениях, помогает бороться с антисемитизмом и ксенофобией. Украина не должна забывать о преступлениях, совершенных против украинских евреев, и никоим образом не отмечать их через почитание их исполнителей», — написал дипломат. 11 декабря Львовский областной совет принял решение провозгласить 2019 год в регионе годом Степана Бандеры в связи с празднованием 110-летия со дня рождения лидера ОУН (Бандера родился 1 января 1909 года). В июле аналогичное решение принял Житомирский областной совет. В начале месяца с предложением к президенту страны Петру Порошенко вернуть Бандере звание Героя Украины обратились депутаты Верховной Рады. Парламентарии уверены, что признание Бандеры национальным героем поможет в борьбе с подрывной деятельностью против Украины в информационном поле, а также остановит «распространение мифов, созданных российской пропагандой». Степан Бандера (1909-1959) был одним из лидеров Организации украинских националистов, выступающей за создание независимого государства на территориях с украиноязычным населением. В 2010 году в период президентства Виктора Ющенко Бандера был посмертно признан Героем Украины, однако впоследствии это решение было отменено судом. '
doc = Doc(text)

# %%
doc.segment(segmenter)
display(doc.tokens[:5])
display(doc.sents[:5])
# Out:
# [DocToken(stop=5, text='Посол'),
#  DocToken(start=6, stop=13, text='Израиля'),
#  DocToken(start=14, stop=16, text='на'),
#  DocToken(start=17, stop=24, text='Украине'),
#  DocToken(start=25, stop=30, text='Йоэль')]
# [DocSent(stop=218, text='Посол Израиля на Украине Йоэль Лион признался, чт..., tokens=[...]),
#  DocSent(start=219, stop=257, text='Свое заявление он разместил в Twitter.', tokens=[...]),
#  DocSent(start=258, stop=424, text='«Я не могу понять, как прославление тех, кто непо..., tokens=[...]),
#  DocSent(start=425, stop=592, text='Украина не должна забывать о преступлениях, совер..., tokens=[...]),
#  DocSent(start=593, stop=798, text='11 декабря Львовский областной совет принял решен..., tokens=[...])]
