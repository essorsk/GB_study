# %% [markdown]
# __1.__ Найти собственные векторы и собственные значения для линейного оператора, заданного матрицей
#
# $$A=\begin{pmatrix}
# -1 & -6\\
# 2 & 6
# \end{pmatrix}.$$

# %% [markdown]
# найдем собственные значения линейного оператора, составив и решив характеристическое уравнение:
# |-1-𝜆        -6|   = 0  <=>   𝜆 ** 2 -5 * 𝜆 + 6 = 0
# | 2         6-𝜆|
#
# Уравнение имеет 2 решение
# 𝜆 = 2   𝜆 = 3
#
#
# найдем собственные векторы вида  (a, b) , подставив полученное собственное значение в выражение  𝐀𝑥=𝜆𝑥
#
#
# x = (a, b)
#
# (-1 -6) (a)  = 𝜆 (a)
# ( 2  6) (b)  =   (b)
#
# 𝜆 = 2
# -a -6b = 2* a
# 2a + 6b = 2 * b
#
#
# a = -2*b
#
# Вектор вида (2, -1) является собственным
#
# 𝜆a = 3
# 3*a = -2*b
#
# Вектор вида (3, -2) является собственным

# %% [markdown]
# __2.__ Дан оператор поворота на 180 градусов, задаваемый матрицей
#
# $$A=\begin{pmatrix}
# -1 & 0\\
# 0 & -1
# \end{pmatrix}.$$
#
# Показать, что __любой__ вектор является для него собственным.

# %% [markdown]
# Проверим, что произвольный вектор x = (a, b) является собственным, решив систему уравнений:
#
#     (-1 0) (a)   = 𝜆 *( a)
#     (0 -1)(b)         ( b)
#
#     -a = 𝜆 * a
#     -b = 𝜆* b
#
#     a (𝜆 +1) = 0
#     b(𝜆 + 1) = 0
#
# Система уравнений имеет бесконечное множество решений (a, b) при (𝜆 = -1).
# Соответственно, любой вектор является собственным для заданной матрицы

# %% [markdown]
# __3.__ Пусть линейный оператор задан матрицей
#
# $$A=\begin{pmatrix}
# 1 & 1\\
# -1 & 3
# \end{pmatrix}.$$
#
# Установить, является ли вектор $x=(1,1)$ собственным вектором этого линейного оператора.

# %% [markdown]
# Предположим, что вектор  𝑥  является собственным вектором заданного линейного оператора
#
#
# (1  1) (1) = 𝜆 (1)  <=>
# (-1 3) (1)     (1)
#
#
# 2 = 𝜆
# 2 = 𝜆
#
# Таким образом, вектор  x=(1,1) является собственным вектором этого линейного оператора, его собственное значение = 2

# %% [markdown]
# __4.__ Пусть линейный оператор задан матрицей
#
# $$A=\begin{pmatrix}
# 0 & 3 & 0\\
# 3 & 0 & 0\\
# 0 & 0 & 3
# \end{pmatrix}.$$
#
# Установить, является ли вектор $x=(3, -3, -4)$ собственным вектором этого линейного оператора.

# %% [markdown]
# ( 0 3 0) (3)     (3)
# (3 0  0) (-3) = 𝜆(-3)
# (0 0 3) (-4)     (-4)
#
# -9 = 3 *𝜆
# 9 = -3 *𝜆
# -12 = -4 *𝜆
#
# Таким образом, вектор  𝑥=(3,-3,-4)  является собственным вектором линейного оператора, заданного матрицей  𝐴 , и его собственное значение составляет  𝜆=3.
